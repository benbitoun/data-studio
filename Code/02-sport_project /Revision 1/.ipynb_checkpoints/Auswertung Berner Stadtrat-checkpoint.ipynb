# %%
import pandas as pd
import numpy as np

# %%
# Identifier (Identifier der Ressource im Quellsystem des Publishers): Traktanden_SR_2018_bis_Heute_CSV
# Titel (Titel der Datei): Traktanden_SR_2018 bis heute mit Beschlüssen
# Beschreibung (Datei-Informationen): Die Traktandenliste aller Geschäfte und Beschlüsse zu den Stadtratssitzungen der Stadt Bern.
# Sprache (Sprache in der diese Datei vorliegt): Deutsch
# Erstellt (Datum der Veröffentlichung dieser Datei): 01.12.2017
# Geändert (Datum der letzten Änderung dieser Datei): 01.12.2017
# Nutzungsbedingungen (Art der Nutzung und Angabepflicht): Freie Nutzung - Quellenangben ist Pflicht (Autor, Titel und Link zum Datensatz).
# Zugangs-URL (Die URL über welche auf die Ressource zugegriffen werden kann): http://www.bern.ch/open-government-data-ogd/ogd-nach-themen/stadtrat-ogd
# Download-URL (URL der Datei um die Ressource direkt heruntergeladen werden kann): http://www.bern.ch/open-government-data-ogd/ogd-nach-themen/stadtrat-ogd/download-stadtraetische-traktanden-und-beschluesse-ogd/traktanden-sr-2018-bis-heute-mit-beschlussen.txt/download
# Dateigrösse (Angabe in Bytes): 46157
# Dateiformat (Datei Typ und Kürzel des Formats): CSV
# Autor der Datei (Ein oder mehrere Autoren dieser Datei): Ratssekretariat des Stadtrats der Stadt Bern
# Dateibezogene Zusatzinformationen (Der richtige Umgang und Interpretation die es ggf. zu berücksichtigen gilt.): Weitere Informationen zu den einzelnen Traktanden und Geschäfte finden Sie als PDF Datei unter http://www.bern.ch/politik-und-verwaltung/stadtrat/sitzung-geschaeft.

# %%
df = pd.read_csv("traktanden_sr_2018.csv", delimiter=";", encoding="Latin 1")
df.head(10)
# Out:
#    Traktanden Nr.                               Traktandierungstitel  \
# 0               1  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...
# 1               1  Dringliches interfraktionelles Postulat BDP/CV...
# 2               1  Dringliche Motion Fraktion FDP/JF (Bernhard Ei...
# 3               2  Dringliche Motion Fraktion GFL/EVP (Manuel C. ...
# 4               3  Dringliche Interpellation Freie Fraktion AL/Ga...
# 5               1  Interfraktionelle Motion GB/JA!, SP, GFL/EVP (...
# 6               2  Motion Fraktion SP/JUSO (Andreas Flückiger/Rol...
# 7               3  Interfraktionelles Postulat SP, GB/JA! (Peter ...
# 8               4  Motion Tania Espinoza Haller (GFL), Bettina Ja...
# 9               5  Interfraktionelle Motion Fraktionen GB/JA!, SP...
#
#   Beschluss Nr. Traktandumstatus Beschluss       Datum
# 0           NaN     Traktandiert       NaN  14.06.2018
# 1           NaN     Traktandiert       NaN  31.05.2018
# 2           NaN     Traktandiert       NaN  17.05.2018
# 3           NaN     Traktandiert       NaN  17.05.2018
# 4           NaN     Traktandiert       NaN  17.05.2018
# 5           NaN     Traktandiert       NaN  03.05.2018
# 6           NaN     Traktandiert       NaN  03.05.2018
# 7           NaN     Traktandiert       NaN  03.05.2018
# 8           NaN     Traktandiert       NaN  03.05.2018
# 9           NaN     Traktandiert       NaN  03.05.2018

# %%
df.shape
# Out:
# (220, 6)

# %%
df.dtypes
# Out:
# Traktanden Nr.           int64
# Traktandierungstitel    object
# Beschluss Nr.           object
# Traktandumstatus        object
# Beschluss               object
# Datum                   object
# dtype: object

# %%
len(df.Traktandierungstitel.value_counts())
# Out:
# 179

# %%
df.Beschluss.value_counts()
# Out:
# Verschiebung                             53
# Kenntnis                                 38
# Ablehnung                                19
# Wahl                                      9
# Erheblicherkl.                            8
# Bewilligung                               7
# Genehmigung                               6
# Erheblicherkl. als Richtlinie             5
# Genehmigung Prüf.bericht                  4
# Fristverl.                                3
# Rückzug                                   2
# Abschreibung                              2
# Erheblicherkl. als Postulat               2
# Teilweise Erheblicherkl. als Postulat     1
# Teilweise Erheblicherkl.                  1
# Verabschiedung zuhanden 2. Lesung         1
# Name: Beschluss, dtype: int64

# %%
df.Datum.dtype
# Out:
# dtype('O')

# %%
#Changing to datetime:
df.Datum.head()
# Out:
# 0    14.06.2018
# 1    31.05.2018
# 2    17.05.2018
# 3    17.05.2018
# 4    17.05.2018
# Name: Datum, dtype: object

# %%
pd.to_datetime(df['Datum'], format="%d.%m.%Y")
#Save into new colum:
df['datum'] = pd.to_datetime(df['Datum'], format="%d.%m.%Y")
df.tail(50)
# Out:
#      Traktanden Nr.                               Traktandierungstitel  \
# 170              16  Interpellation Fraktion FDP (Bernhard Eicher, ...
# 171              17  Motion Luzius Theiler (GPB-DA): Besserer Recht...
# 172              18  Postulat Fraktion SP (Katharina Altas/Halua Pi...
# 173              19  Motion Fraktion AL/GPB-DA/PdA+ (Daniel Egloff,...
# 174              20  Motion Fraktion SVP (Roland Iseli, SVP): Einhe...
# 175              21  Motion Henri-Charles Beuchat (SVP): Gewalttäti...
# 176              22  Postulat Fraktion SVP (Alexander Feuz/Roland J...
# 177              23  Motion Henri-Charles Beuchat (SVP): Schluss mi...
# 178               1  Protokollgenehmigungen Stadtrat 2017 (Protokol...
# 179               2  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...
# 180               3  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...
# 181               4  Gaswerkareal: Bericht Entwicklungs- und Planun...
# 182               5  Interfraktionelle Motion GB/JA!, GLP (Franzisk...
# 183               6  Motion Fraktion GB/JA! (Stéphanie Penher, GB/L...
# 184               7  Interpellation Fraktion GLP (Melanie Mettler, ...
# 185               8  Ratssekretariat: Antrag auf provisorische Anst...
# 186               9  Dringliche interfraktionelle Interpellation Fr...
# 187              10  Dringliche interfraktionelle Interpellation SV...
# 188              11  Dringliche interfraktionelle Motion SVP, BDP/C...
# 189              12  Dringliche Motion Fraktion SVP (Alexander Feuz...
# 190              13  Grundstück Bern 5/1354 (Lorrainestrasse 49 und...
# 191              14  Interfraktionelle Motion FDP, SVP, BDP/CVP (Ch...
# 192              15  Interfraktionelles Postulat BDP/CVP, FDP, GLP,...
# 193              16  Interfraktionelle Motion SVP, FDP, BDP/CVP (Ru...
# 194              17  Interpellation Fraktion SVP (Alexander Feuz/Ro...
# 195              18  Interfraktionelles Postulat SVP, FDP (Rudolf F...
# 196              19  Interfraktionelle Motion SVP, FDP (Rudolf Frie...
# 197              20  Motion Ingrid Kissling-Näf (SP) und Ueli Jaisl...
# 198              21  Interfraktionelle Motion FDP, SVP (Christoph Z...
# 199              22  Interfraktionelle Motion GB/JA!, GLP (Hasim Sa...
# 200              23  Interfraktionelle Motion FDP, SVP, BDP/CVP (Ch...
# 201               1  Wahl des Präsidiums und des Büros des Stadtrat...
# 202               2  Aufsichtskommission (AK): Wahl des Präsidiums ...
# 203               3  Kommission für Finanzen, Sicherheit und Umwelt...
# 204               4  Kommission für Planung, Verkehr und Stadtgrün ...
# 205               5  Kommission für Soziales, Bildung und Kultur (S...
# 206               6  Agglomerationskommission (AKO): Ersatzwahl ein...
# 207               7  Wahl in Schulkommission (Schulkommission Matte...
# 208               8  Kleine Anfrage Henri-Charles Beuchat (SVP): Na...
# 209               9  Kleine Anfrage Barbara Freiburghaus (FDP), Mil...
# 210              10  Dringliche Interpellation Lionel Gaudy, Philip...
# 211              11  Interfraktionelles Postulat SP, GFL, BDP/CVP (...
# 212              12  Jugendmotion (Paula Zysset/Frédéric Mader): EW...
# 213              13  Interfraktionelle Motion SVP, FDP (Rudolf Frie...
# 214              14  Interfraktionelle Interpellation BDP/CVP, FDP,...
# 215              15  Interfraktionelle Motion GFL/EVP, BDP/CVP, FDP...
# 216              16  Postulat Fraktion SP (Katharina Altas/Halua Pi...
# 217              17  Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# 218              18  Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# 219              19  Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
#
#     Beschluss Nr. Traktandumstatus       Beschluss       Datum      datum
# 170       2018-58      Beschlossen        Kenntnis  01.02.2018 2018-02-01
# 171       2018-59      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 172       2018-60      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 173       2018-61      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 174       2018-62      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 175       2018-63      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 176       2018-64      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 177       2018-65      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 178       2018-20      Beschlossen     Genehmigung  25.01.2018 2018-01-25
# 179       2018-21      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 180       2018-22      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 181       2018-23      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 182       2018-24      Beschlossen      Fristverl.  25.01.2018 2018-01-25
# 183       2018-25      Beschlossen      Fristverl.  25.01.2018 2018-01-25
# 184       2018-26      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 185       2018-27      Beschlossen            Wahl  25.01.2018 2018-01-25
# 186       2018-28      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 187       2018-29      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 188       2018-30      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 189       2018-31      Beschlossen       Ablehnung  25.01.2018 2018-01-25
# 190       2018-32      Beschlossen     Bewilligung  25.01.2018 2018-01-25
# 191       2018-33      Beschlossen       Ablehnung  25.01.2018 2018-01-25
# 192       2018-34      Beschlossen         Rückzug  25.01.2018 2018-01-25
# 193       2018-35      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 194       2018-36      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 195       2018-37      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 196       2018-38      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 197       2018-39      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 198       2018-40      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 199       2018-41      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 200       2018-42      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 201        2018-1      Beschlossen            Wahl  11.01.2018 2018-01-11
# 202        2018-2      Beschlossen            Wahl  11.01.2018 2018-01-11
# 203        2018-3      Beschlossen            Wahl  11.01.2018 2018-01-11
# 204        2018-4      Beschlossen            Wahl  11.01.2018 2018-01-11
# 205        2018-5      Beschlossen            Wahl  11.01.2018 2018-01-11
# 206        2018-6      Beschlossen            Wahl  11.01.2018 2018-01-11
# 207        2018-7      Beschlossen            Wahl  11.01.2018 2018-01-11
# 208        2018-8      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 209        2018-9      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 210       2018-10      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 211       2018-11      Beschlossen  Erheblicherkl.  11.01.2018 2018-01-11
# 212       2018-12      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 213       2018-13      Beschlossen       Ablehnung  11.01.2018 2018-01-11
# 214       2018-14      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 215       2018-15      Beschlossen       Ablehnung  11.01.2018 2018-01-11
# 216       2018-16      Beschlossen    Verschiebung  11.01.2018 2018-01-11
# 217       2018-17      Beschlossen    Verschiebung  11.01.2018 2018-01-11
# 218       2018-18      Beschlossen    Verschiebung  11.01.2018 2018-01-11
# 219       2018-19      Beschlossen    Verschiebung  11.01.2018 2018-01-11

# %%
len(df[df['Traktandierungstitel'].str.contains("Christa Ammann", na=False)])
# Out:
# 8

# %%
#Mehrere Konditionen:
df[(df.Traktandierungstitel.str.contains('Christa Ammann', na=False) & (df.Traktandumstatus == 'Beschlossen'))]
# Out:
#      Traktanden Nr.                               Traktandierungstitel  \
# 73               15  Dringliche interfraktionelle Motion SP/JUSO, G...
# 87                4  Motion Tamara Funiciello (JUSO), Christa Amman...
# 91                8  Interfraktionelle Motion AL/GPB-DA/PdA+, SP, G...
# 139              10  Dringliche interfraktionelle Motion GB/JA!, SP...
# 151              22  Interfraktionelle Motion AL/GPB-DA/PdA+, SP, G...
#
#     Beschluss Nr. Traktandumstatus                      Beschluss       Datum  \
# 73       2018-151      Beschlossen  Erheblicherkl. als Richtlinie  22.03.2018
# 87       2018-117      Beschlossen  Erheblicherkl. als Richtlinie  08.03.2018
# 91       2018-121      Beschlossen       Teilweise Erheblicherkl.  08.03.2018
# 139       2018-75      Beschlossen  Erheblicherkl. als Richtlinie  15.02.2018
# 151       2018-87      Beschlossen                   Verschiebung  15.02.2018
#
#          datum
# 73  2018-03-22
# 87  2018-03-08
# 91  2018-03-08
# 139 2018-02-15
# 151 2018-02-15

# %%
df.Traktandierungstitel.dtype
# Out:
# dtype('O')

# %%
df['Traktierungstitel'] = df['Traktandierungstitel'].astype(str)
df.dtypes
# Out:
# Traktanden Nr.                   int64
# Traktandierungstitel            object
# Beschluss Nr.                   object
# Traktandumstatus                object
# Beschluss                       object
# Datum                           object
# datum                   datetime64[ns]
# Traktierungstitel               object
# dtype: object

# %%
#Funktion:
import re
def get_vorstoss(row):
    if re.findall(r"[\w]* Motion ", row['Traktandierungstitel']):   
        print('Motion')
        return 'Motion'
    
    elif re.findall(r"Motion ", row['Traktandierungstitel']):   
        print('Motion')
        return 'Motion'
    
    elif re.findall(r"[\w]* Postulat ", row['Traktandierungstitel']):   
        print('Postulat')
        return 'Postulat'
    
    elif re.findall(r"Postulat ", row['Traktandierungstitel']):   
        print('Postulat')
        return 'Postulat'
    
    elif re.findall(r"[\w]* Interpellation ", row['Traktandierungstitel']):   
        print('Interpellation')
        return 'Interpellation'
    
    elif re.findall(r"Interpellation ", row['Traktandierungstitel']):   
        print('Interpellation')
        return 'Interpellation'
    
    elif re.findall(r"[\w]* Anfrage ", row['Traktandierungstitel']):   
        print('Kleine Anfrage')
        return 'Kleine Anfrage'
    
    else:
        print('damn')

# %%
df['vorstoesse'] = df.apply(get_vorstoss,axis=1)
df.head(50)
# Out:
# Motion
# Postulat
# Motion
# Motion
# Interpellation
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Postulat
# Postulat
# Postulat
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Postulat
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Kleine Anfrage
# Kleine Anfrage
# Interpellation
# nope
# Kleine Anfrage
# Motion
# nope
# nope
# Motion
# Motion
# Motion
# Motion
# nope
# nope
# Interpellation
# Motion
# nope
# nope
# Motion
# Motion
# Motion
# Motion
# Postulat
# Interpellation
# nope
# nope
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# nope
# nope
# nope
# nope
# nope
# Postulat
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Motion
# Motion
# Postulat
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# nope
# Postulat
# Motion
# Interpellation
# Postulat
# Motion
# Postulat
# Postulat
# Interpellation
# Kleine Anfrage
# Kleine Anfrage
# nope
# nope
# Postulat
# Interpellation
# Motion
# Motion
# Interpellation
# nope
# Motion
# Motion
# nope
# Postulat
# Motion
# Motion
# Motion
# Postulat
# Motion
# Motion
# Interpellation
# Motion
# Interpellation
# nope
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# nope
# nope
# Motion
# Motion
# Motion
# Interpellation
# Postulat
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Postulat
# Interpellation
# Kleine Anfrage
# nope
# nope
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Postulat
# Postulat
# Postulat
# Motion
# Postulat
# Postulat
# Interpellation
# Motion
# Postulat
# Motion
# Motion
# Motion
# Postulat
# Motion
# nope
# Kleine Anfrage
# Kleine Anfrage
# nope
# Motion
# Motion
# Interpellation
# nope
# Interpellation
# Interpellation
# Motion
# Motion
# nope
# Motion
# Postulat
# Motion
# Interpellation
# Postulat
# Motion
# Motion
# Motion
# Motion
# Motion
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# Kleine Anfrage
# Kleine Anfrage
# Interpellation
# Postulat
# nope
# Motion
# Interpellation
# Motion
# Postulat
# Motion
# Motion
# Motion
#     Traktanden Nr.                               Traktandierungstitel  \
# 0                1  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...
# 1                1  Dringliches interfraktionelles Postulat BDP/CV...
# 2                1  Dringliche Motion Fraktion FDP/JF (Bernhard Ei...
# 3                2  Dringliche Motion Fraktion GFL/EVP (Manuel C. ...
# 4                3  Dringliche Interpellation Freie Fraktion AL/Ga...
# 5                1  Interfraktionelle Motion GB/JA!, SP, GFL/EVP (...
# 6                2  Motion Fraktion SP/JUSO (Andreas Flückiger/Rol...
# 7                3  Interfraktionelles Postulat SP, GB/JA! (Peter ...
# 8                4  Motion Tania Espinoza Haller (GFL), Bettina Ja...
# 9                5  Interfraktionelle Motion Fraktionen GB/JA!, SP...
# 10               6  Postulat Fraktion SP (Peter Marbet/Michael Sut...
# 11               7  Interfraktionelle Motion GB/JA!, GLP (Lea Bill...
# 12               8  Motion Fraktion SP (Peter Marbet, SP): Erhalt ...
# 13               9  Postulat Fraktion SP (Fuat Köçer, SP): Die Jug...
# 14              10  Motion Fraktion BDP/CVP (Edith Leibundgut, CVP...
# 15              11  Interfraktionelle Motion SP, BDP/CVP (Lea Kusa...
# 16              12  Postulat Fraktion GLP (Daniel Imthurn/Jürg Wed...
# 17              13  lnterfraktionelles Postulat SP/JUSO, GB/JA! (S...
# 18              14  Postulat Fraktion GB/JA! (Stéphanie Penher/Fra...
# 19              15  Postulat Fraktion GLP (Melanie Mettler/Sandra ...
# 20              16  Postulat Fraktion GB/JA! (Esther Oester/Stépha...
# 21              17  Motion Fraktion GB/JA! (Esther Oester/Stéphani...
# 22              18  Motion Fraktion GLP (Melanie Mettler/Sandra Ry...
# 23              19  Postulat Fraktion GB/JA! (Regula Tschanz, GB):...
# 24              20  Motion Aufsichtskommission AK (Kurt Hirsbrunne...
# 25              21  Postulat Fraktion FDP (Bernhard Eicher, FDP): ...
# 26              22  Interfraktionelle Motion SP, GB/JA!, GLP, GFL/...
# 27              23  Interfraktionelle Motion Fraktion GB/JA!, SP (...
# 28              24  Motion Fraktion GB/JA! (Leena Schmitter, GB/Le...
# 29              25  Motion Fraktion GB/JA! (Regula Bühlmann, GB): ...
# 30              26  Motion Fraktion GB/JA! (Cristina Anliker-Manso...
# 31              27  Interfraktionelle Motion FDP, SP, BDP/CVP, GFL...
# 32              28  Interfraktionelle Motion SP/JUSO, BDP/CVP (Rit...
# 33              29  Interfraktionelle Motion SP, GFL/EVP, GLP, GB/...
# 34              30  Motion Fraktion FDP (Alexandre Schmidt, FDP): ...
# 35               1  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...
# 36               2  Kleine Anfrage Barbara Freiburghaus (FDP), Lio...
# 37               3  Dringliche Interpellation Fraktion SVP (Alexan...
# 38               1  Protokollgenehmigungen Stadtrat 2018 (Protokol...
# 39               2  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...
# 40               3  Dringliche Motion Lionel Gaudy, Philip Kohli (...
# 41               4  Dringliche lnterpellation Fraktion SP/JUSO (Ti...
# 42               5  Schwarztorstrasse, Einführung Velogegenverkehr...
# 43               6  Motion Fraktion SVP (Alexander Feuz/Roland Jak...
# 44               7  Motion Fraktion SVP (Alexander Feuz/Roland Jak...
# 45               8  Motion Fraktion SP (David Stampfli/Michael Sut...
# 46               9  Motion Fraktion SP (David Stampfli/Michael Sut...
# 47              10  Reglement vom 28. September 1997 über die Erhe...
# 48              11  Vereinbarungen mit dem BSC Young Boys (YB) und...
# 49              12  Interpellation Henri-Charles Beuchat (SVP): Be...
#
#    Beschluss Nr. Traktandumstatus Beschluss       Datum      datum  \
# 0            NaN     Traktandiert       NaN  14.06.2018 2018-06-14
# 1            NaN     Traktandiert       NaN  31.05.2018 2018-05-31
# 2            NaN     Traktandiert       NaN  17.05.2018 2018-05-17
# 3            NaN     Traktandiert       NaN  17.05.2018 2018-05-17
# 4            NaN     Traktandiert       NaN  17.05.2018 2018-05-17
# 5            NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 6            NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 7            NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 8            NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 9            NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 10           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 11           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 12           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 13           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 14           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 15           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 16           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 17           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 18           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 19           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 20           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 21           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 22           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 23           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 24           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 25           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 26           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 27           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 28           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 29           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 30           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 31           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 32           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 33           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 34           NaN     Traktandiert       NaN  03.05.2018 2018-05-03
# 35           NaN     Traktandiert       NaN  26.04.2018 2018-04-26
# 36           NaN     Traktandiert       NaN  26.04.2018 2018-04-26
# 37           NaN     Traktandiert       NaN  26.04.2018 2018-04-26
# 38      2018-162      Beschlossen       NaN  05.04.2018 2018-04-05
# 39      2018-163      Beschlossen       NaN  05.04.2018 2018-04-05
# 40      2018-164      Beschlossen       NaN  05.04.2018 2018-04-05
# 41      2018-165      Beschlossen       NaN  05.04.2018 2018-04-05
# 42      2018-166      Beschlossen       NaN  05.04.2018 2018-04-05
# 43      2018-167      Beschlossen       NaN  05.04.2018 2018-04-05
# 44      2018-168      Beschlossen       NaN  05.04.2018 2018-04-05
# 45      2018-169      Beschlossen       NaN  05.04.2018 2018-04-05
# 46      2018-170      Beschlossen       NaN  05.04.2018 2018-04-05
# 47      2018-171      Beschlossen       NaN  05.04.2018 2018-04-05
# 48      2018-172      Beschlossen       NaN  05.04.2018 2018-04-05
# 49      2018-173      Beschlossen       NaN  05.04.2018 2018-04-05
#
#                                     Traktierungstitel      vorstoesse
# 0   Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...          Motion
# 1   Dringliches interfraktionelles Postulat BDP/CV...        Postulat
# 2   Dringliche Motion Fraktion FDP/JF (Bernhard Ei...          Motion
# 3   Dringliche Motion Fraktion GFL/EVP (Manuel C. ...          Motion
# 4   Dringliche Interpellation Freie Fraktion AL/Ga...  Interpellation
# 5   Interfraktionelle Motion GB/JA!, SP, GFL/EVP (...          Motion
# 6   Motion Fraktion SP/JUSO (Andreas Flückiger/Rol...          Motion
# 7   Interfraktionelles Postulat SP, GB/JA! (Peter ...        Postulat
# 8   Motion Tania Espinoza Haller (GFL), Bettina Ja...          Motion
# 9   Interfraktionelle Motion Fraktionen GB/JA!, SP...          Motion
# 10  Postulat Fraktion SP (Peter Marbet/Michael Sut...        Postulat
# 11  Interfraktionelle Motion GB/JA!, GLP (Lea Bill...          Motion
# 12  Motion Fraktion SP (Peter Marbet, SP): Erhalt ...          Motion
# 13  Postulat Fraktion SP (Fuat Köçer, SP): Die Jug...        Postulat
# 14  Motion Fraktion BDP/CVP (Edith Leibundgut, CVP...          Motion
# 15  Interfraktionelle Motion SP, BDP/CVP (Lea Kusa...          Motion
# 16  Postulat Fraktion GLP (Daniel Imthurn/Jürg Wed...        Postulat
# 17  lnterfraktionelles Postulat SP/JUSO, GB/JA! (S...        Postulat
# 18  Postulat Fraktion GB/JA! (Stéphanie Penher/Fra...        Postulat
# 19  Postulat Fraktion GLP (Melanie Mettler/Sandra ...        Postulat
# 20  Postulat Fraktion GB/JA! (Esther Oester/Stépha...        Postulat
# 21  Motion Fraktion GB/JA! (Esther Oester/Stéphani...          Motion
# 22  Motion Fraktion GLP (Melanie Mettler/Sandra Ry...          Motion
# 23  Postulat Fraktion GB/JA! (Regula Tschanz, GB):...        Postulat
# 24  Motion Aufsichtskommission AK (Kurt Hirsbrunne...          Motion
# 25  Postulat Fraktion FDP (Bernhard Eicher, FDP): ...        Postulat
# 26  Interfraktionelle Motion SP, GB/JA!, GLP, GFL/...          Motion
# 27  Interfraktionelle Motion Fraktion GB/JA!, SP (...          Motion
# 28  Motion Fraktion GB/JA! (Leena Schmitter, GB/Le...          Motion
# 29  Motion Fraktion GB/JA! (Regula Bühlmann, GB): ...          Motion
# 30  Motion Fraktion GB/JA! (Cristina Anliker-Manso...          Motion
# 31  Interfraktionelle Motion FDP, SP, BDP/CVP, GFL...          Motion
# 32  Interfraktionelle Motion SP/JUSO, BDP/CVP (Rit...          Motion
# 33  Interfraktionelle Motion SP, GFL/EVP, GLP, GB/...          Motion
# 34  Motion Fraktion FDP (Alexandre Schmidt, FDP): ...          Motion
# 35  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...  Kleine Anfrage
# 36  Kleine Anfrage Barbara Freiburghaus (FDP), Lio...  Kleine Anfrage
# 37  Dringliche Interpellation Fraktion SVP (Alexan...  Interpellation
# 38  Protokollgenehmigungen Stadtrat 2018 (Protokol...            None
# 39  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...  Kleine Anfrage
# 40  Dringliche Motion Lionel Gaudy, Philip Kohli (...          Motion
# 41  Dringliche lnterpellation Fraktion SP/JUSO (Ti...            None
# 42  Schwarztorstrasse, Einführung Velogegenverkehr...            None
# 43  Motion Fraktion SVP (Alexander Feuz/Roland Jak...          Motion
# 44  Motion Fraktion SVP (Alexander Feuz/Roland Jak...          Motion
# 45  Motion Fraktion SP (David Stampfli/Michael Sut...          Motion
# 46  Motion Fraktion SP (David Stampfli/Michael Sut...          Motion
# 47  Reglement vom 28. September 1997 über die Erhe...            None
# 48  Vereinbarungen mit dem BSC Young Boys (YB) und...            None
# 49  Interpellation Henri-Charles Beuchat (SVP): Be...  Interpellation
