# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.style.use('ggplot')
import dateutil.parser
import re
import time

# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
datestring = time.strftime("%m-%h-%d")
datestring
# Out:
# '07-Jul-17'

# %% [markdown]
# # Functions for Scraper

# %%
#Function to pick every other player (because of duplicates):
def removing_every_other_player(x):
    return x[::2]

# %%
#Functions for visiting players profil page:
def alter(player):
    try:
        return player.find('th', text = re.compile('Alter:')).findNext('td').string
    except:
        return None

# %%
def im_team_seit(player):
    try:
        return player.find('th', text = re.compile('Im Team seit:')).findNext('td').string.strip()
    except:
        return None

# %%
def position(player):
    if player == None:
        return None
    else:
        return player.find('th', text = re.compile('Position:'))\
    .findNext('td').string.strip()

# %%
def groesse(player):
    try:
        return int(player.find('th', text = re.compile('Größe:')).findNext('td').string.replace(',', '').replace(' m', ''))
    except:
        return None

# %%
def club(player):
    if player.find('th', text = re.compile('Aktueller Verein:')).string.strip() == 'Aktueller Verein:':
        return player.find('th', text = re.compile('Aktueller')).findNext('td').findNext('a').find('img').get('alt')
    elif player.find('th', text = re.compile('Current club:')).string.strip() == 'Current club:':
        return player.find('th', text = re.compile('Current club:')).findNext('td').findNext('a').find('img').get('alt')
    else:
        return

# %%
#Function to extract the former club:
def ex_club(player):
    try:
        return player.find('td', {'class': 'hauptlink no-border-links hide-for-small vereinsname'}).findNext('a').string
    except:
        return None

# %%
def agent(player):
    try:
        return player.find('th', text = re.compile("Spielerberater:"))\
    .findNext('td').findNext('a').get('title')
    except:
        return None

# %%
def marktwert(player):
    try:
        return player.find('div', {'class': 'right-td'}).findNext('a').text.replace(',', '').replace(' Mio. €', '0000').replace(' Tsd. €', '0000')
    except:
        return None

# %%
def shoes(player):
    try:
        return player.find('th', text = re.compile("Ausrüster:")).findNext('td')\
    .findNext('a').findNext('img').get('title')
    except:
        return None

# %%
def ausgeliehen_von(player):
    try:
        return player.find('th', text = re.compile("Ausgeliehen von:")).findNext('td').find('a').text
    except:
        return None

# %%
def Minuten(x):
    try:
        return int(x.find('td', {'class': 'zentriert'}).find_next('td', {'class': 'rechts'}).string.replace("'", ''))
    except:
        return None

# %% [markdown]
# # Scraping

# %%
#This site doesn't like to be scraped, therefore I'll use this header:
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
#url = "http://www.transfermarkt.com/raiffeisen-super-league/transfers/wettbewerb/C1/saison_id/2017"
url = "http://www.transfermarkt.ch/raiffeisen-super-league/transfers/wettbewerb/C1/saison_id/2017"
response = requests.get(url, headers=headers)
transfermarkt_soup = BeautifulSoup(response.text, 'html.parser')

# %%
transfermarkt = transfermarkt_soup.find_all('a', {'class': 'spielprofil_tooltip'})

# %%
#not what that does - have to check again.
transfermarkt.pop(0)
#Only picking every other player
transfermarkt = removing_every_other_player(transfermarkt)

# %%
transfer_dict = []

for spieler in transfermarkt:
    
    #Name
    Name = spieler.string
    print(Name)
    
    #Link
    spieler_link = spieler['href']
    spieler_link = 'http://www.transfermarkt.ch' + spieler_link
    #print(spieler_link)
    
    #Visiting players profil pages
    spieler_profil = requests.get(spieler_link, headers=headers)
    spieler_profil = BeautifulSoup(spieler_profil.text, 'html.parser')
    #print(spieler_profil)
    
    Alter = alter(spieler_profil)
    #print(Alter)
    Grösse = groesse(spieler_profil)
    #print(Grösse)
    Position = position(spieler_profil)
    #print(Position)
    Verein = club(spieler_profil)
    #print(Verein)
    Ex_Verein = ex_club(spieler_profil)
    #print(Ex_Verein)
    Agent = agent(spieler_profil)
    #print(Agent)
    Ausrüster = shoes(spieler_profil)
    #print(Ausrüster)
    Im_team_seit = im_team_seit(spieler_profil)
    #print(Im_team_seit)
    Marktwert = marktwert(spieler_profil)
    Ausgeliehen_von = ausgeliehen_von(spieler_profil)
    #print(Marktwert)

    #Visiting Leistungsdaten pages
    spieler_leistungsdaten_link = spieler_link.replace('profil', 'leistungsdaten')
    spieler_leistungsdaten_link = spieler_leistungsdaten_link + '/plus/0?saison=ges'
    spieler_leistungsdaten = requests.get(spieler_leistungsdaten_link, headers=headers)
    spieler_leistungsdaten = BeautifulSoup(spieler_leistungsdaten.text, 'html.parser')
    print(spieler_leistungsdaten_link)
    
    #This is possible to do in a list because every player has these parameters
    Spiele = spieler_leistungsdaten.find('tfoot')
    leistungsdaten = Spiele.find_all('td', {'class': 'zentriert'})
    leistungsdaten_list = []
    for Daten in leistungsdaten:
        Daten = Daten.string
        leistungsdaten_list.append(Daten)
    
    if len(leistungsdaten_list) > 6:
        Totalspiele = int(leistungsdaten_list[0].replace('-', '0'))
        Tore = int(leistungsdaten_list[1].replace('-', '0'))
        Vorlagen = 0
        Gelbe_Karten = int(leistungsdaten_list[2].replace('-', '0'))
        Gelb_Rote_Karten = int(leistungsdaten_list[3].replace('-', '0'))
        Rote_Karten = int(leistungsdaten_list[4].replace('-', '0'))
    
    else:
        Totalspiele = int(leistungsdaten_list[0].replace('-', '0'))
        Tore = int(leistungsdaten_list[1].replace('-', '0'))
        Vorlagen = int(leistungsdaten_list[2].replace('-', '0'))
        Gelbe_Karten = int(leistungsdaten_list[3].replace('-', '0'))
        Gelb_Rote_Karten = int(leistungsdaten_list[4].replace('-', '0'))
        Rote_Karten = int(leistungsdaten_list[5].replace('-', '0'))
        #print(leistungsdaten_list)
        
#Minuten = Minuten(Spiele)
    
    Spieler_Dict = {"Name": Name,
                    "Alter": Alter,
                    "URL": spieler_link,
                    "Grösse": Grösse,
                    "Position": Position,
                    "Verein": Verein,
                    "Wechsel von": Ex_Verein,
                    "Ausgeliehen von": Ausgeliehen_von,
                    "Agent": Agent,
                    "Ausrüster": Ausrüster,
                    "Im Team seit": Im_team_seit,
                    "Total Spiele": Totalspiele,
                    "Tore": Tore,
                    "Vorlagen": Vorlagen,
                    "Gelbe Karten": Gelbe_Karten,
                    "Gelb-Rote Karten": Gelb_Rote_Karten,
                    "Rote Karten": Rote_Karten,
                    'Marktwert': Marktwert,
                    'Minuten': Minuten
                    }
    
    transfer_dict.append(Spieler_Dict)
# Out:
# R. van Wolfswinkel
# http://www.transfermarkt.ch/ricky-van-wolfswinkel/leistungsdaten/spieler/41355/plus/0?saison=ges
# F. Frei
# http://www.transfermarkt.ch/fabian-frei/leistungsdaten/spieler/52595/plus/0?saison=ges
# http://www.transfermarkt.ch/dzengis-cavusevic/leistungsdaten/spieler/68287/plus/0?saison=ges
# A. Simonyan
# http://www.transfermarkt.ch/artem-simonyan/leistungsdaten/spieler/235349/plus/0?saison=ges
# Kay Voser
# http://www.transfermarkt.ch/kay-voser/leistungsdaten/spieler/40140/plus/0?saison=ges
# N. Stettler
# http://www.transfermarkt.ch/nicolas-stettler/leistungsdaten/spieler/192621/plus/0?saison=ges
# M. Graf
# http://www.transfermarkt.ch/marvin-graf/leistungsdaten/spieler/183314/plus/0?saison=ges
# K. Pagliuca
# http://www.transfermarkt.ch/kilian-pagliuca/leistungsdaten/spieler/192652/plus/0?saison=ges
# Y. Fillion
# http://www.transfermarkt.ch/yann-alexandre-fillion/leistungsdaten/spieler/364653/plus/0?saison=ges
# D. Chiumiento
# http://www.transfermarkt.ch/davide-chiumiento/leistungsdaten/spieler/17332/plus/0?saison=ges
# G. Yapi
# http://www.transfermarkt.ch/gilles-yapi/leistungsdaten/spieler/13105/plus/0?saison=ges
# N. Baumann
# http://www.transfermarkt.ch/novem-baumann/leistungsdaten/spieler/183308/plus/0?saison=ges
# A. Sadrijaj
# http://www.transfermarkt.ch/albin-sadrijaj/leistungsdaten/spieler/258289/plus/0?saison=ges
# A. Favre
# http://www.transfermarkt.ch/anthony-favre/leistungsdaten/spieler/10059/plus/0?saison=ges
# M. Muheim
# http://www.transfermarkt.ch/miro-muheim/leistungsdaten/spieler/298603/plus/0?saison=ges

# %% [markdown]
# # Making a Dataframe and cleaning it

# %%
#Making the DataFrame
df_transfers = pd.DataFrame(transfer_dict)

# %%
df_transfers.head()
# Out:
#              Agent Alter Ausgeliehen von                         Ausrüster  \
# 0      Louis Laros    29            None                              None
# 1  Giallanza Sport    29            None
# 2             ESHA    21            None  Nike Nike Mercurial Superfly 360
# 3   SOCCER MONDIAL    20            None  Nike Nike Hypervenom Phantom III
# 4              IFM    29            None         Nike Nike Magista Obra II
#
#    Gelb-Rote Karten  Gelbe Karten Grösse Im Team seit Marktwert  \
# 0                 1            37   None   01.07.2017   3000000
# 1                 0            50   None   01.01.2018   2250000
# 2                 0            17   None   02.10.2017   5000000
# 3                 0            11   None   01.07.2018   6000000
# 4                 1            64   None   10.01.2018   1500000
#
#                              Minuten                Name  \
# 0  <function Minuten at 0x1153ad950>  R. van Wolfswinkel
# 1  <function Minuten at 0x1153ad950>             F. Frei
# 2  <function Minuten at 0x1153ad950>            A. Ajeti
# 3  <function Minuten at 0x1153ad950>          D. Oberlin
# 4  <function Minuten at 0x1153ad950>          V. Stocker
#
#                              Position  Rote Karten  Tore  Total Spiele  \
# 0               Sturm - Mittelstürmer            0   138           354
# 1  Mittelfeld - Defensives Mittelfeld            1    73           457
# 2               Sturm - Mittelstürmer            0    64           172
# 3               Sturm - Mittelstürmer            1    44           130
# 4  Mittelfeld - Offensives Mittelfeld            2    96           407
#
#                                                  URL         Verein  Vorlagen  \
# 0  http://www.transfermarkt.ch/ricky-van-wolfswin...  FC Basel 1893        28
# 1  http://www.transfermarkt.ch/fabian-frei/profil...  FC Basel 1893        62
# 2  http://www.transfermarkt.ch/albian-ajeti/profi...  FC Basel 1893        16
# 3  http://www.transfermarkt.ch/dimitri-oberlin/pr...  FC Basel 1893        14
# 4  http://www.transfermarkt.ch/valentin-stocker/p...  FC Basel 1893       100
#
#        Wechsel von
# 0  Vitesse Arnheim
# 1   1.FSV Mainz 05
# 2    FC St. Gallen
# 3      RB Salzburg
# 4       Hertha BSC

# %%
df_transfers.shape
# Out:
# (414, 19)

# %%
#Test for one club:
df_transfers[df_transfers['Verein'] == 'BSC Young Boys'].head()
# Out:
#                     Agent Alter Ausgeliehen von  \
# 123                  None    19            None
# 336           Sport 11 AG    24            None
# 341  TJP-Sport-Management    24            None
# 342   Signature - ISCM AG    21            None
# 343         Sport Profile    25            None
#
#                             Ausrüster  Gelb-Rote Karten  Gelbe Karten Grösse  \
# 123         Nike Nike Magista Obra II                 0             6   None
# 336  Nike Nike Mercurial Superfly 360                 0            27   None
# 341                                                   1            10   None
# 342         Nike Nike Magista Obra II                 0            12   None
# 343                              None                 0             8   None
#
#     Im Team seit Marktwert                            Minuten  \
# 123   01.07.2017   4500000  <function Minuten at 0x1153ad950>
# 336   01.07.2017   4000000  <function Minuten at 0x1153ad950>
# 341   26.08.2017   2500000  <function Minuten at 0x1153ad950>
# 342   01.07.2017   6500000  <function Minuten at 0x1153ad950>
# 343   19.07.2017   4500000  <function Minuten at 0x1153ad950>
#
#                   Name                           Position  Rote Karten  Tore  \
# 123         J. Lotomba       Abwehr - Rechter Verteidiger            0    10
# 336       C. Fassnacht                Sturm - Rechtsaußen            0    70
# 341  N. Moumi Ngamaleu                Sturm - Rechtsaußen            0    15
# 342             D. Sow  Mittelfeld - Zentrales Mittelfeld            0    10
# 343           J. Nsame              Sturm - Mittelstürmer            0    40
#
#      Total Spiele                                                URL  \
# 123           116  http://www.transfermarkt.ch/jordan-lotomba/pro...
# 336           233  http://www.transfermarkt.ch/christian-fassnach...
# 341            84  http://www.transfermarkt.ch/nicolas-moumi-ngam...
# 342           115  http://www.transfermarkt.ch/djibril-sow/profil...
# 343           105  http://www.transfermarkt.ch/jean-pierre-nsame/...
#
#              Verein  Vorlagen      Wechsel von
# 123  BSC Young Boys         7   Lausanne-Sport
# 336  BSC Young Boys        19          FC Thun
# 341  BSC Young Boys        11       SCR Altach
# 342  BSC Young Boys        14  Bor. M'gladbach
# 343  BSC Young Boys        12      Servette FC

# %%
#Dealing with the loan of players:
#1.) Sorting out only the loaned players. Moving column to the back. 
#2.) Deleting last club column. Renaming the loaned column. 
#3.) Concating it with the original file.
#So now the last club column is correct. 
df_ausgeliehen = df_transfers[df_transfers['Ausgeliehen von'].notnull()]

def change_column_order(df, col_name, index):
    cols = df.columns.tolist()
    cols.remove(col_name)
    cols.insert(index, col_name)
    return df[cols]

#moving column to the back
df = change_column_order(df_ausgeliehen, 'Ausgeliehen von', 17)

del df['Wechsel von']

#Renaming last column
df.columns = df.columns.str.replace('Ausgeliehen von','Wechsel von')

#Prepping original dataframe
df_transfers = df_transfers[df_transfers['Ausgeliehen von'].isnull()]

del df_transfers['Ausgeliehen von']

#concating the two
df_SL_transfers = pd.concat([df, df_transfers], ignore_index=True)

#Dropping any duplicate values
df_SL_transfers = df_SL_transfers.drop_duplicates()

# %%
# Making sure all the clubs are spelt correctly:

#Dealing with the name problem of the Clubs (FCB, Grasshoppers etc.). Two different names for FCB, Lausanne, GC, FCSG in the columns.
def fcb_lausanne(x):
    return x.replace(' 1893', '').replace('Grasshoppers', 'Grasshopper Club Zürich').replace('Lausanne-Sport', 'FC Lausanne-Sport').replace('FC St. Gallen', 'FC St. Gallen 1879')

def fcb(x):
    return x.replace(' 1893', '')

df_SL_transfers['*Wechsel von*'] = df_SL_transfers['Wechsel von'].apply(fcb_lausanne)
df_SL_transfers['*Verein*'] = df_SL_transfers['Verein'].apply(fcb)

# %%
df_SL_transfers.head()
# Out:
#              Agent Alter                  Ausrüster  Gelb-Rote Karten  \
# 0       Footuro AG    21  Nike Nike Magista Obra II                 0
# 1             ESHA    20                       None                 0
# 2  Sportfront GmbH    24  Nike Nike Magista Obra II                 0
# 6    Gol de Classe    21                       None                 0
# 7  Sportfront GmbH    23                       None                 0
#
#    Gelbe Karten Grösse Im Team seit Marktwert  \
# 0             3   None   11.01.2018   6000000
# 1             6   None   15.01.2018   5000000
# 2             6   None   05.07.2018   6500000
# 6            25   None   26.02.2018   3000000
# 7            13   None   22.06.2018   5000000
#
#                              Minuten        Name  \
# 0  <function Minuten at 0x1153ad950>  D. Nikolic
# 1  <function Minuten at 0x1153ad950>   D. Schmid
# 2  <function Minuten at 0x1153ad950>    M. Salvi
# 6  <function Minuten at 0x1153ad950>  P. Pacheco
# 7  <function Minuten at 0x1153ad950>    R. Kapic
#
#                              Position  Rote Karten  Tore  Total Spiele  \
# 0                             Torwart            0     0            45
# 1  Mittelfeld - Offensives Mittelfeld            0    11            84
# 2                             Torwart            0     0           150
# 6           Abwehr - Innenverteidiger            1     3            90
# 7   Mittelfeld - Zentrales Mittelfeld            0    18            84
#
#                                                  URL              Verein  \
# 0  http://www.transfermarkt.ch/djordje-nikolic/pr...             FC Thun
# 1  http://www.transfermarkt.ch/dominik-schmid/pro...   FC Lausanne-Sport
# 2  http://www.transfermarkt.ch/mirko-salvi/profil...           FC Luzern
# 6  http://www.transfermarkt.ch/pedro-pacheco/prof...  FC Rapperswil-Jona
# 7  http://www.transfermarkt.ch/rifet-kapic/profil...    Sheriff Tiraspol
#
#    Vorlagen              Wechsel von            *Wechsel von*  \
# 0         0            FC Basel 1893                 FC Basel
# 1         1            FC Basel 1893                 FC Basel
# 2         0  Grasshopper Club Zürich  Grasshopper Club Zürich
# 6         1            FC Basel 1893                 FC Basel
# 7         5  Grasshopper Club Zürich  Grasshopper Club Zürich
#
#              *Verein*
# 0             FC Thun
# 1   FC Lausanne-Sport
# 2           FC Luzern
# 6  FC Rapperswil-Jona
# 7    Sheriff Tiraspol

# %%
#Checking the dtypes:
df_SL_transfers.dtypes
# Out:
# Agent               object
# Alter               object
# Ausrüster           object
# Gelb-Rote Karten     int64
# Gelbe Karten         int64
# Grösse              object
# Im Team seit        object
# Marktwert           object
# Minuten             object
# Name                object
# Position            object
# Rote Karten          int64
# Tore                 int64
# Total Spiele         int64
# URL                 object
# Verein              object
# Vorlagen             int64
# Wechsel von         object
# *Wechsel von*       object
# *Verein*            object
# dtype: object

# %%
#Changing the datype of Marktwert to an float, but some '-' and ' ' that cause problems when trying to convert:
df_SL_transfers['Marktwert'].replace(['-', ' '], ['NaN', 'NaN'], inplace=True)

# %%
#Test:
df_SL_transfers['Marktwert'].head()
# Out:
# 0    6000000
# 1    5000000
# 2    6500000
# 6    3000000
# 7    5000000
# Name: Marktwert, dtype: object

# %%
df_SL_transfers['Marktwert'] = df_SL_transfers.Marktwert.astype(float)

# %%
df_SL_transfers.dtypes
# Out:
# Agent                object
# Alter                object
# Ausrüster            object
# Gelb-Rote Karten      int64
# Gelbe Karten          int64
# Grösse               object
# Im Team seit         object
# Marktwert           float64
# Minuten              object
# Name                 object
# Position             object
# Rote Karten           int64
# Tore                  int64
# Total Spiele          int64
# URL                  object
# Verein               object
# Vorlagen              int64
# Wechsel von          object
# *Wechsel von*        object
# *Verein*             object
# dtype: object

# %%
#Safeing dataframe:
df_SL_transfers.to_csv('SL_transfers.csv', index=False)

# %% [markdown]
# ## Analyzing the data

# %%
#Shoes:
df_SL_transfers['Ausrüster'].value_counts()
# Out:
#                                     43
# Nike Nike Mercurial Superfly 360    20
# Nike Nike Mercurial Vapor 360       17
# Nike Nike Magista Obra II           16
# Nike Nike Hypervenom Phantom III    13
# Nike Nike Tiempo Legend VII FG       7
# Vereinslos                           2
# Name: Ausrüster, dtype: int64

# %%
#Top 10 most active agents in Switzerland:
df_SL_transfers['Agent'].value_counts().head(10)
# Out:
# SOCCER MONDIAL        15
# IFM                   14
# ohne Berater          12
# Familienangehörige    10
# Sportfront GmbH        9
# Footuro AG             7
# Giallanza Sport        6
# ESHA                   6
# SBE Management AG      5
# Soccerdome             4
# Name: Agent, dtype: int64

# %%
#Biggest player agency:
soccer_mondial = df_SL_transfers[df_SL_transfers. Agent == 'SOCCER MONDIAL']
soccer_mondial.head()
# Out:
#              Agent Alter                         Ausrüster  Gelb-Rote Karten  \
# 18  SOCCER MONDIAL    21         Nike Nike Magista Obra II                 2
# 38  SOCCER MONDIAL    20  Nike Nike Hypervenom Phantom III                 0
# 49  SOCCER MONDIAL    21     Nike Nike Mercurial Vapor 360                 1
# 73  SOCCER MONDIAL    24                              None                 1
# 87  SOCCER MONDIAL    20  Nike Nike Mercurial Superfly 360                 0
#
#     Gelbe Karten Grösse Im Team seit Marktwert  \
# 18             9   None   11.01.2018   2250000
# 38            11   None   01.07.2018   6000000
# 49            23   None   01.07.2017   5000000
# 73            19   None   01.07.2018   4000000
# 87            10   None   29.01.2018   5000000
#
#                               Minuten         Name  \
# 18  <function Minuten at 0x1153ad950>     A. Grgic
# 38  <function Minuten at 0x1153ad950>   D. Oberlin
# 49  <function Minuten at 0x1153ad950>  N. Manzambi
# 73  <function Minuten at 0x1153ad950>   A. Avdijaj
# 87  <function Minuten at 0x1153ad950>   N. Sukacev
#
#                              Position  Rote Karten  Tore  Total Spiele  \
# 18  Mittelfeld - Zentrales Mittelfeld            0     9           114
# 38              Sturm - Mittelstürmer            1    44           130
# 49              Sturm - Mittelstürmer            0    43           124
# 73              Sturm - Mittelstürmer            0    72           188
# 87                Sturm - Rechtsaußen            1     7            58
#
#                                                   URL  \
# 18  http://www.transfermarkt.ch/anto-grgic/profil/...
# 38  http://www.transfermarkt.ch/dimitri-oberlin/pr...
# 49  http://www.transfermarkt.ch/neftali-manzambi/p...
# 73  http://www.transfermarkt.ch/albion-avdijaj/pro...
# 87  http://www.transfermarkt.ch/nikola-sukacev/pro...
#
#                      Verein  Vorlagen    Wechsel von            *Wechsel von*  \
# 18                  FC Sion        10  VfB Stuttgart            VfB Stuttgart
# 38            FC Basel 1893        14    RB Salzburg              RB Salzburg
# 49            FC Basel 1893         6   FC Basel U21             FC Basel U21
# 73               Vereinslos        20   Grasshoppers  Grasshopper Club Zürich
# 87  Grasshopper Club Zürich         2  GC Zürich U21            GC Zürich U21
#
#                    *Verein*
# 18                  FC Sion
# 38                 FC Basel
# 49                 FC Basel
# 73               Vereinslos
# 87  Grasshopper Club Zürich

# %%
#Players with Soccer Mondial:
soccer_mondial.Name
# Out:
# 18         A. Grgic
# 38       D. Oberlin
# 49      N. Manzambi
# 73       A. Avdijaj
# 87       N. Sukacev
# 92     H. Tabakovic
# 99        J. Bamert
# 112       M. Dabbur
# 242    M. Schneuwly
# 255        M. Angha
# 275    N. Lüchinger
# 278      V. Salatic
# 339    E. Schirinzi
# 350        M. Bürki
# 391     T. Schättin
# Name: Name, dtype: object

# %%
#Number of players with Soccer Mondial:
soccer_mondial.Name.count()
# Out:
# 15

# %%
#Market value of players with Soccer Mondial:
soccer_mondial.groupby('Name').Marktwert.value_counts()
# Out:
# Name          Marktwert
# A. Avdijaj    4000000      1
# A. Grgic      2250000      1
# D. Oberlin    6000000      1
# E. Schirinzi  2750000      1
# H. Tabakovic  3500000      1
# J. Bamert     1100000      1
# M. Angha      7000000      1
# M. Bürki      4000000      1
# M. Dabbur                  1
# M. Schneuwly  6000000      1
# N. Lüchinger  7500000      1
# N. Manzambi   5000000      1
# N. Sukacev    5000000      1
# T. Schättin   5500000      1
# V. Salatic    8000000      1
# Name: Marktwert, dtype: int64

# %%
#How can I sum all the market values of the players from Soccer mondial?

# %% [markdown]
# # Creating Dataframes to establish gain, losses of each club

# %%
#Importing Super League Clubs
df_SL_Vereine = pd.read_csv("Super_League_Vereine_18_19.csv")

# %%
df_SL_Vereine.head(10)
# Out:
#                  SL-Verein Group 1 Group 2
# 0                 FC Basel     FCB     FCB
# 1                  FC Sion    Sion    Rest
# 2                FC Lugano  Lugano    Rest
# 3        FC Lausanne-Sport    Rest    Rest
# 4           BSC Young Boys    Rest    Rest
# 5  Grasshopper Club Zürich    Rest    Rest
# 6                FC Luzern    Rest    Rest
# 7                FC Zürich    Rest    Rest
# 8       FC St. Gallen 1879    Rest    Rest
# 9                  FC Thun    Rest    Rest

# %%
#Merging the Files
df_SL_Zuzuege = df_SL_transfers.merge(df_SL_Vereine, left_on = '*Verein*', right_on ='SL-Verein') 
df_SL_Abgaenge = df_SL_transfers.merge(df_SL_Vereine, left_on = '*Wechsel von*', right_on ='SL-Verein')

# %%
#Having a look:
df_SL_Zuzuege.head()
# Out:
#           Agent Alter                         Ausrüster  Gelb-Rote Karten  \
# 0    Footuro AG    21         Nike Nike Magista Obra II                 0
# 1           IFM    22  Nike Nike Mercurial Superfly 360                 0
# 2           IFM    23                                                   0
# 3           IFM    23  Nike Nike Hypervenom Phantom III                 0
# 4  ohne Berater    24                              None                 0
#
#    Gelbe Karten Grösse Im Team seit  Marktwert  \
# 0             3   None   11.01.2018  6000000.0
# 1             5   None   01.07.2017  6000000.0
# 2            10   None   01.07.2018  8000000.0
# 3            18   None   11.07.2017  1250000.0
# 4            17   None   01.07.2017  4000000.0
#
#                              Minuten         Name   ...   Total Spiele  \
# 0  <function Minuten at 0x1153ad950>   D. Nikolic   ...             45
# 1  <function Minuten at 0x1153ad950>  N. Hunziker   ...            108
# 2  <function Minuten at 0x1153ad950>    G. Karlen   ...            132
# 3  <function Minuten at 0x1153ad950>    Roy Gelmi   ...            134
# 4  <function Minuten at 0x1153ad950>  N. Da Silva   ...            160
#
#                                                  URL   Verein  Vorlagen  \
# 0  http://www.transfermarkt.ch/djordje-nikolic/pr...  FC Thun         0
# 1  http://www.transfermarkt.ch/nicolas-hunziker/p...  FC Thun         4
# 2  http://www.transfermarkt.ch/gregory-karlen/pro...  FC Thun        10
# 3  http://www.transfermarkt.ch/roy-gelmi/profil/s...  FC Thun         1
# 4  http://www.transfermarkt.ch/nuno-da-silva/prof...  FC Thun        27
#
#       Wechsel von       *Wechsel von*  *Verein* SL-Verein Group 1 Group 2
# 0   FC Basel 1893            FC Basel   FC Thun   FC Thun    Rest    Rest
# 1        FC Basel            FC Basel   FC Thun   FC Thun    Rest    Rest
# 2         FC Sion             FC Sion   FC Thun   FC Thun    Rest    Rest
# 3   FC St. Gallen  FC St. Gallen 1879   FC Thun   FC Thun    Rest    Rest
# 4  FC Breitenrain      FC Breitenrain   FC Thun   FC Thun    Rest    Rest
#
# [5 rows x 23 columns]

# %%
#Having a look:
df_SL_Abgaenge.head()
# Out:
#                  Agent Alter                         Ausrüster  \
# 0           Footuro AG    21         Nike Nike Magista Obra II
# 1                 ESHA    20                              None
# 2        Gol de Classe    21                              None
# 3                 None    26         Nike Nike Magista Obra II
# 4  AR Sport Management    24  Nike Nike Mercurial Superfly 360
#
#    Gelb-Rote Karten  Gelbe Karten Grösse Im Team seit  Marktwert  \
# 0                 0             3   None   11.01.2018  6000000.0
# 1                 0             6   None   15.01.2018  5000000.0
# 2                 0            25   None   26.02.2018  3000000.0
# 3                 2            48   None   31.08.2016  2500000.0
# 4                 0            20   None   03.01.2018  7500000.0
#
#                              Minuten        Name   ...   Total Spiele  \
# 0  <function Minuten at 0x1153ad950>  D. Nikolic   ...             45
# 1  <function Minuten at 0x1153ad950>   D. Schmid   ...             84
# 2  <function Minuten at 0x1153ad950>  P. Pacheco   ...             90
# 3  <function Minuten at 0x1153ad950>  L. Lacroix   ...            191
# 4  <function Minuten at 0x1153ad950>   A. Sporar   ...            187
#
#                                                  URL              Verein  \
# 0  http://www.transfermarkt.ch/djordje-nikolic/pr...             FC Thun
# 1  http://www.transfermarkt.ch/dominik-schmid/pro...   FC Lausanne-Sport
# 2  http://www.transfermarkt.ch/pedro-pacheco/prof...  FC Rapperswil-Jona
# 3  http://www.transfermarkt.ch/leo-lacroix/profil...    AS Saint-Étienne
# 4  http://www.transfermarkt.ch/andraz-sporar/prof...   Slovan Bratislava
#
#    Vorlagen    Wechsel von *Wechsel von*            *Verein* SL-Verein  \
# 0         0  FC Basel 1893      FC Basel             FC Thun  FC Basel
# 1         1  FC Basel 1893      FC Basel   FC Lausanne-Sport  FC Basel
# 2         1  FC Basel 1893      FC Basel  FC Rapperswil-Jona  FC Basel
# 3         2       FC Basel      FC Basel    AS Saint-Étienne  FC Basel
# 4        26       FC Basel      FC Basel   Slovan Bratislava  FC Basel
#
#   Group 1 Group 2
# 0     FCB     FCB
# 1     FCB     FCB
# 2     FCB     FCB
# 3     FCB     FCB
# 4     FCB     FCB
#
# [5 rows x 23 columns]

# %%
#Working out total market values of bought players
Total_Marktwert_Zuzuege = pd.DataFrame(df_SL_Zuzuege.groupby('*Verein*')['Marktwert'].sum())
Total_Marktwert_Zuzuege.tail(3)
# Out:
#                           Marktwert
# *Verein*
# FC Thun                  51250000.0
# FC Zürich                29000000.0
# Grasshopper Club Zürich  54000000.0

# %%
#Working out total market values of sold players
Total_Marktwert_Abgaenge = pd.DataFrame(df_SL_Abgaenge.groupby('*Wechsel von*')['Marktwert'].sum())
Total_Marktwert_Abgaenge.tail(3)
# Out:
#                           Marktwert
# *Wechsel von*
# FC Thun                  24000000.0
# FC Zürich                40000000.0
# Grasshopper Club Zürich  49850000.0

# %%
#Resetting the Index of both the new frames
Total_Marktwert_Abgaenge.reset_index(inplace=True)
Total_Marktwert_Zuzuege.reset_index(inplace=True)

# %%
#Merging the data sets
Zuzuege_Abgaenge = Total_Marktwert_Zuzuege.merge(Total_Marktwert_Abgaenge, left_on = '*Verein*', right_on ='*Wechsel von*')

# %%
#Working out the difference
Zuzuege_Abgaenge['Transfer_Differenz_Marktwert'] = Zuzuege_Abgaenge['Marktwert_x'] - Zuzuege_Abgaenge['Marktwert_y']

# %%
#Deleting the columns we don't need:
del Zuzuege_Abgaenge['*Wechsel von*']

# %%
#del Zuzuege_Abgaenge['level_0']

# %%
#del Zuzuege_Abgaenge['index']

# %%
Zuzuege_Abgaenge.tail()
# Out:
#                   *Verein*  Marktwert_x  Marktwert_y  \
# 5                  FC Sion   42350000.0   85750000.0
# 6       FC St. Gallen 1879   43250000.0   40000000.0
# 7                  FC Thun   51250000.0   24000000.0
# 8                FC Zürich   29000000.0   40000000.0
# 9  Grasshopper Club Zürich   54000000.0   49850000.0
#
#    Transfer_Differenz_Marktwert
# 5                   -43400000.0
# 6                     3250000.0
# 7                    27250000.0
# 8                   -11000000.0
# 9                     4150000.0

# %%
#Renaming columns
Zuzuege_Abgaenge.columns = ['verein', 'gesamt_marktwert_zuzuege', 'gesamt_marktwert_abgaenge', 'gesamt_differenz_marktwert']

# %%
Zuzuege_Abgaenge
# Out:
#                     verein  gesamt_marktwert_zuzuege  \
# 0           BSC Young Boys                63500000.0
# 1                 FC Basel                38000000.0
# 2        FC Lausanne-Sport                42750000.0
# 3                FC Lugano                76750000.0
# 4                FC Luzern                36750000.0
# 5                  FC Sion                42350000.0
# 6       FC St. Gallen 1879                43250000.0
# 7                  FC Thun                51250000.0
# 8  Grasshopper Club Zürich                54000000.0
#
#    gesamt_marktwert_abgaenge  gesamt_differenz_marktwert
# 0                 70750000.0                  -7250000.0
# 1                 52250000.0                 -14250000.0
# 2                 34250000.0                   8500000.0
# 3                 34750000.0                  42000000.0
# 4                 35500000.0                   1250000.0
# 5                 85750000.0                 -43400000.0
# 6                 40000000.0                   3250000.0
# 7                 24000000.0                  27250000.0
# 8                 49850000.0                   4150000.0

# %%
#Safeing dataframe as csv:
Zuzuege_Abgaenge.to_csv('zuzuege_abgaenge_SL.csv', index=False)

# %%
#For goals:
Total_Marktwert_Zuzuege = pd.DataFrame(df_SL_Zuzuege.groupby('*Verein*')['Tore'].sum())
Total_Marktwert_Abgaenge = pd.DataFrame(df_SL_Abgaenge.groupby('*Wechsel von*')['Tore'].sum())

# %%
Total_Marktwert_Abgaenge.reset_index(inplace=True)
Total_Marktwert_Zuzuege.reset_index(inplace=True)

# %%
#Merging the two frames:
Tore = Total_Marktwert_Zuzuege.merge(Total_Marktwert_Abgaenge, left_on = '*Verein*', right_on ='*Wechsel von*')

# %%
#Working out the difference:
Tore['Transfer_Differenz_Tore'] = Tore['Tore_x'] - Tore['Tore_y']

# %%
del Tore['*Wechsel von*']

# %%
Tore.tail()
# Out:
#                   *Verein*  Tore_x  Tore_y  Transfer_Differenz_Tore
# 5                  FC Sion     172     579                     -407
# 6       FC St. Gallen 1879     229     265                      -36
# 7                  FC Thun     235     263                      -28
# 8                FC Zürich     130     253                     -123
# 9  Grasshopper Club Zürich     388     498                     -110

# %%
#For Assists:

Total_Marktwert_Zuzuege = pd.DataFrame(df_SL_Zuzuege.groupby('*Verein*')['Vorlagen'].sum())
Total_Marktwert_Abgaenge = pd.DataFrame(df_SL_Abgaenge.groupby('*Wechsel von*')['Vorlagen'].sum())
Total_Marktwert_Abgaenge.reset_index(inplace=True)
Total_Marktwert_Zuzuege.reset_index(inplace=True)
Vorlagen = Total_Marktwert_Zuzuege.merge(Total_Marktwert_Abgaenge, left_on = '*Verein*', right_on ='*Wechsel von*')
Vorlagen['Transfer_Differenz_Vorlagen'] = Vorlagen['Vorlagen_x'] - Vorlagen['Vorlagen_y']
del Vorlagen['*Wechsel von*']

# %%
Vorlagen.tail()
# Out:
#                   *Verein*  Vorlagen_x  Vorlagen_y  \
# 5                  FC Sion         104         314
# 6       FC St. Gallen 1879         149         153
# 7                  FC Thun         128          80
# 8                FC Zürich          84         215
# 9  Grasshopper Club Zürich         169         166
#
#    Transfer_Differenz_Vorlagen
# 5                         -210
# 6                           -4
# 7                           48
# 8                         -131
# 9                            3

# %%
#The minutes in total:
Total_Marktwert_Zuzuege = pd.DataFrame(df_SL_Zuzuege.groupby('*Verein*')['Total Spiele'].sum())
Total_Marktwert_Abgaenge = pd.DataFrame(df_SL_Abgaenge.groupby('*Wechsel von*')['Total Spiele'].sum())
#Resetting the Index of both the new frames
Total_Marktwert_Abgaenge.reset_index(inplace=True)
Total_Marktwert_Zuzuege.reset_index(inplace=True)

# %%
#Merging the two frames:
Minuten = Total_Marktwert_Zuzuege.merge(Total_Marktwert_Abgaenge, left_on = '*Verein*', right_on ='*Wechsel von*')

# %%
Minuten.tail()
# Out:
#                   *Verein*  Total Spiele_x            *Wechsel von*  \
# 5                  FC Sion            1763                  FC Sion
# 6       FC St. Gallen 1879            1976       FC St. Gallen 1879
# 7                  FC Thun            1471                  FC Thun
# 8                FC Zürich            1099                FC Zürich
# 9  Grasshopper Club Zürich            2284  Grasshopper Club Zürich
#
#    Total Spiele_y
# 5            3548
# 6            1994
# 7            1494
# 8            3159
# 9            2506

# %%
Minuten['Transfer_Differenz_Minuten'] = Minuten['Total Spiele_x'] - Minuten['Total Spiele_y']

# %%
del Minuten['*Wechsel von*']

# %%
Zuzuege_Abgaenge.tail()
# Out:
#                     verein  gesamt_marktwert_zuzuege  \
# 5                  FC Sion                42350000.0
# 6       FC St. Gallen 1879                43250000.0
# 7                  FC Thun                51250000.0
# 8                FC Zürich                29000000.0
# 9  Grasshopper Club Zürich                54000000.0
#
#    gesamt_marktwert_abgaenge  gesamt_differenz_marktwert
# 5                 85750000.0                 -43400000.0
# 6                 40000000.0                   3250000.0
# 7                 24000000.0                  27250000.0
# 8                 40000000.0                 -11000000.0
# 9                 49850000.0                   4150000.0

# %%
Minuten.tail()
# Out:
#                   *Verein*  Total Spiele_x  Total Spiele_y  \
# 5                  FC Sion            1763            3548
# 6       FC St. Gallen 1879            1976            1994
# 7                  FC Thun            1471            1494
# 8                FC Zürich            1099            3159
# 9  Grasshopper Club Zürich            2284            2506
#
#    Transfer_Differenz_Minuten
# 5                       -1785
# 6                         -18
# 7                         -23
# 8                       -2060
# 9                        -222

# %%
Zuzuege_Abgaenge.dtypes
# Out:
# verein                         object
# gesamt_marktwert_zuzuege      float64
# gesamt_marktwert_abgaenge     float64
# gesamt_differenz_marktwert    float64
# dtype: object

# %%
Tore.dtypes
# Out:
# *Verein*                   object
# Tore_x                      int64
# Tore_y                      int64
# Transfer_Differenz_Tore     int64
# dtype: object

# %%
#Now merging Zuzuege_Abgaenge, Tore und Vorlagen und Minuten. 
#Deleting the columns I don't need and renaming the ones I do.
df_bilanz = Zuzuege_Abgaenge.merge(Tore, left_on = 'verein', right_on ='*Verein*')
df_bilanz = df_bilanz.merge(Vorlagen, left_on = 'verein', right_on ='*Verein*')
df_bilanz = df_bilanz.merge(Minuten, left_on = 'verein', right_on ='*Verein*')

# %%
df_bilanz.shape
# Out:
# (10, 16)

# %%
#del df_transferbilanz['*Verein*_x']
#del df_transferbilanz['*Verein*_y']
#del df_transferbilanz['*Verein*']

# %%
df_bilanz.tail(5)
# Out:
#                     verein  gesamt_marktwert_zuzuege  \
# 5                  FC Sion                42350000.0
# 6       FC St. Gallen 1879                43250000.0
# 7                  FC Thun                51250000.0
# 8                FC Zürich                29000000.0
# 9  Grasshopper Club Zürich                54000000.0
#
#    gesamt_marktwert_abgaenge  gesamt_differenz_marktwert  \
# 5                 85750000.0                 -43400000.0
# 6                 40000000.0                   3250000.0
# 7                 24000000.0                  27250000.0
# 8                 40000000.0                 -11000000.0
# 9                 49850000.0                   4150000.0
#
#                 *Verein*_x  Tore_x  Tore_y  Transfer_Differenz_Tore  \
# 5                  FC Sion     172     579                     -407
# 6       FC St. Gallen 1879     229     265                      -36
# 7                  FC Thun     235     263                      -28
# 8                FC Zürich     130     253                     -123
# 9  Grasshopper Club Zürich     388     498                     -110
#
#                 *Verein*_y  Vorlagen_x  Vorlagen_y  \
# 5                  FC Sion         104         314
# 6       FC St. Gallen 1879         149         153
# 7                  FC Thun         128          80
# 8                FC Zürich          84         215
# 9  Grasshopper Club Zürich         169         166
#
#    Transfer_Differenz_Vorlagen                 *Verein*  Total Spiele_x  \
# 5                         -210                  FC Sion            1763
# 6                           -4       FC St. Gallen 1879            1976
# 7                           48                  FC Thun            1471
# 8                         -131                FC Zürich            1099
# 9                            3  Grasshopper Club Zürich            2284
#
#    Total Spiele_y  Transfer_Differenz_Minuten
# 5            3548                       -1785
# 6            1994                         -18
# 7            1494                         -23
# 8            3159                       -2060
# 9            2506                        -222

# %%
#Safeing merged dataframe as csv:
df_bilanz.to_csv('transferbilanz_SL.csv', index=False)

# %%
df_bilanz.head()
# Out:
#               verein  gesamt_marktwert_zuzuege  gesamt_marktwert_abgaenge  \
# 0     BSC Young Boys                63500000.0                 70750000.0
# 1           FC Basel                38000000.0                 52250000.0
# 2  FC Lausanne-Sport                42750000.0                 34250000.0
# 3          FC Lugano                76750000.0                 34750000.0
# 4          FC Luzern                36750000.0                 35500000.0
#
#    gesamt_differenz_marktwert         *Verein*_x  Tore_x  Tore_y  \
# 0                  -7250000.0     BSC Young Boys     234     380
# 1                 -14250000.0           FC Basel     552     441
# 2                   8500000.0  FC Lausanne-Sport     255     424
# 3                  42000000.0          FC Lugano     502     242
# 4                   1250000.0          FC Luzern     176     241
#
#    Transfer_Differenz_Tore         *Verein*_y  Vorlagen_x  Vorlagen_y  \
# 0                     -146     BSC Young Boys         119         257
# 1                      111           FC Basel         258         262
# 2                     -169  FC Lausanne-Sport          79         279
# 3                      260          FC Lugano         191         170
# 4                      -65          FC Luzern         134         117
#
#    Transfer_Differenz_Vorlagen           *Verein*  Total Spiele_x  \
# 0                         -138     BSC Young Boys            1283
# 1                           -4           FC Basel            2126
# 2                         -200  FC Lausanne-Sport            1594
# 3                           21          FC Lugano            2926
# 4                           17          FC Luzern            1922
#
#    Total Spiele_y  Transfer_Differenz_Minuten
# 0            2432                       -1149
# 1            2607                        -481
# 2            3216                       -1622
# 3            3052                        -126
# 4            2644                        -722

# %%
df_bilanz.drop(['*Verein*_x', '*Verein*_y', '*Verein*'], axis=1, inplace=True)

# %%
df_bilanz.head(1)
# Out:
#            verein  gesamt_marktwert_zuzuege  gesamt_marktwert_abgaenge  \
# 0  BSC Young Boys                63500000.0                 70750000.0
#
#    gesamt_differenz_marktwert  Tore_x  Tore_y  Transfer_Differenz_Tore  \
# 0                  -7250000.0     234     380                     -146
#
#    Vorlagen_x  Vorlagen_y  Transfer_Differenz_Vorlagen  Total Spiele_x  \
# 0         119         257                         -138            1283
#
#    Total Spiele_y  Transfer_Differenz_Minuten
# 0            2432                       -1149

# %%
#import re
#dropper = [col for col in df_transferbilanz.columns if len(re.findall(r"_x", col))!=0]
#dropper

# %%
df_bilanz.columns = ['verein', 'total_marktwert_zuzuege', 'total_marktwert_abgaenge', 'differenz_marktwert', 'total_tore_zuzuege', 'total_tore_abgaenge', 'tore_differenz', 'total_vorlagen_zuzuege', 'total_vorlagen_abgaenge', 'vorlagen-differenz', 'total_spiele_zuzuege', 'total_spiele_abgaenge', 'total-spiel-differenz']

# %%
df_bilanz.head()
# Out:
#                               verein  total_marktwert_zuzuege  \
# verein
# BSC Young Boys        BSC Young Boys               63500000.0
# FC Basel                    FC Basel               38000000.0
# FC Lausanne-Sport  FC Lausanne-Sport               42750000.0
# FC Lugano                  FC Lugano               76750000.0
# FC Luzern                  FC Luzern               36750000.0
#
#                    total_marktwert_abgaenge  differenz_marktwert  \
# verein
# BSC Young Boys                   70750000.0           -7250000.0
# FC Basel                         52250000.0          -14250000.0
# FC Lausanne-Sport                34250000.0            8500000.0
# FC Lugano                        34750000.0           42000000.0
# FC Luzern                        35500000.0            1250000.0
#
#                    total_tore_zuzuege  total_tore_abgaenge  tore_differenz  \
# verein
# BSC Young Boys                    234                  380            -146
# FC Basel                          552                  441             111
# FC Lausanne-Sport                 255                  424            -169
# FC Lugano                         502                  242             260
# FC Luzern                         176                  241             -65
#
#                    total_vorlagen_zuzuege  total_vorlagen_abgaenge  \
# verein
# BSC Young Boys                        119                      257
# FC Basel                              258                      262
# FC Lausanne-Sport                      79                      279
# FC Lugano                             191                      170
# FC Luzern                             134                      117
#
#                    vorlagen-differenz  total_spiele_zuzuege  \
# verein
# BSC Young Boys                   -138                  1283
# FC Basel                           -4                  2126
# FC Lausanne-Sport                -200                  1594
# FC Lugano                          21                  2926
# FC Luzern                          17                  1922
#
#                    total_spiele_abgaenge  total-spiel-differenz
# verein
# BSC Young Boys                      2432                  -1149
# FC Basel                            2607                   -481
# FC Lausanne-Sport                   3216                  -1622
# FC Lugano                           3052                   -126
# FC Luzern                           2644                   -722

# %%
#Safeing cleaned dataframe as csv:
df_bilanz.to_csv('transferbilanz_cleaned_SL.csv', index=False)

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Most active player agents

# %%
fig, ax = plt.subplots(figsize =(15,10))

#Font
csfont = {'fontname':'DIN Condensed'}

df_SL_transfers['Agent'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', color= "#0C2340")

ax.set_facecolor("#EBEBEB")

ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey')
#Getting rid of the ax.y
ax.grid(False, axis='y')

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tick_params(
    #axis='x',
    top=False,
    which=False,
    left=False,
    right=False,
    bottom=False,
    labeltop=False,
    labelbottom=False)

#Labels and title
ax.set_xlabel('Players under contract', **csfont, fontsize=12)
ax.set_title("Ranking the Most Active Player Agents of the Swiss Football League ", **csfont, pad=40, fontsize=24)

plt.gcf().text(0.5, 0.9, "Football isn't only about Players and Coaches. These are the agencies that broker the most deals behind the scenes.", ha="center", fontsize=14)

ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14, 16])
ax.set_xticklabels(["", 2, 4, 6, 8, 10, 12, 14, 16])




#Saving
plt.savefig('Agents.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Agents.png', transparent=True, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize =(15,10))

#Font
csfont = {'fontname':'DIN Condensed'}

df_SL_transfers['Agent'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', color= "#0C2340")

ax.set_facecolor("#EBEBEB")

ax.xaxis.grid(color='white', linestyle=':', linewidth=1)


ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tick_params(
    #axis='x',
    top=False,
    which=False,
    left=False,
    right=False,
    bottom=False,
    labeltop=False,
    labelbottom=False)

#Labels and title and subtitle
#ax.set_xlabel('Traded players under contract', **csfont, fontsize=12)
ax.set_title("Ranking the Most Active Player Agents of the Swiss Football League ", **csfont, pad=40, fontsize=24)

plt.gcf().text(0.5, 0.9, "Football isn't only about Players and Coaches. These are the agencies that broker the most deals behind the scenes.", ha="center", fontsize=14)

ax.set_xticks([0, 2, 4, 6, 8, 10, 12, 14, 16])
ax.set_xticklabels(["", 2, 4, 6, 8, 10, 12, 14, 16])

# xticks & yticks have empty lists to reduce white space in plot
ax.grid(False)

ax.tick_params(left=False)
plt.xticks([])


#plt.yticks([])
#plt.tight_layout()

#Bars free:
for i, bar in enumerate(ax.patches):
    print(i)
    print(bar)
    
    #Now numbers inside of bars
    value = bar.get_width() -1
    x_pos = bar.get_width() -0.5
    y_pos = i
    ax.text(x_pos, y_pos, round(value,1), va='center', ha = "right", color="white", fontweight="bold")
    
#Legend   
ax.legend(loc='lower right', title='Number of traded players under contract ', frameon=False)


#Saving
plt.savefig('Agents_bars_free.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Agents_bars_free.png', transparent=True, bbox_inches='tight')
# Out:
# 0
# Rectangle(xy=(0, -0.25), width=4, height=0.5, angle=0)
# 1
# Rectangle(xy=(0, 0.75), width=5, height=0.5, angle=0)
# 2
# Rectangle(xy=(0, 1.75), width=6, height=0.5, angle=0)
# 3
# Rectangle(xy=(0, 2.75), width=6, height=0.5, angle=0)
# 4
# Rectangle(xy=(0, 3.75), width=7, height=0.5, angle=0)
# 5
# Rectangle(xy=(0, 4.75), width=9, height=0.5, angle=0)
# 6
# Rectangle(xy=(0, 5.75), width=10, height=0.5, angle=0)
# 7
# Rectangle(xy=(0, 6.75), width=12, height=0.5, angle=0)
# 8
# Rectangle(xy=(0, 7.75), width=14, height=0.5, angle=0)
# 9
# Rectangle(xy=(0, 8.75), width=15, height=0.5, angle=0)

# %%
##Safing the dataframe in a new one and making the club name also the Index, useful when making the graphs
df_bilanz_new = df_bilanz
from matplotlib.ticker import FuncFormatter

#Step 1: Build a function
def with_words(value, pos):
    millions = int(value/1000000)
   # print(pos)
    return "{} million".format(int(millions))

def with_commas(value, pos):
    return "{:,}".format(int(value))

#Step 2: Use FuncFormatter with that function
formatter = FuncFormatter(with_commas)

# %% [markdown]
# ### Differenz der Spielermarktwerte

# %%
fig, ax = plt.subplots(figsize =(15,10))

#Font
csfont = {'fontname':'DIN Condensed'}

df_bilanz_new['differenz_marktwert'].sort_values().plot(kind='barh', ax = ax, legend=False, color=['#0C2340'])
plt.axes

ax.set_facecolor("#EBEBEB")


#grid
ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey')
#Getting rid of the ax.y
ax.grid(False, axis='y')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)


#Labels and title
ax.set_title("FC Lugano and FC Thun spent big and brought in Players with a high market value", **csfont, pad=40, fontsize=24)
plt.gcf().text(0.5, 0.9, "Total difference of market value of the players joining or leaving the teams", ha="center", fontsize=14)
ax.set_ylabel('')

#Ticks
ax.tick_params(left=False)
ax.tick_params(bottom=False)

#Showing Median
median = df_bilanz_new['differenz_marktwert'].median()
ax.plot([median, median], [-4, 10], c='darkgrey', linestyle=':')
ax.annotate(s='Median of all clubs', xy=(4000,3.5), color='black')

#Formatting x-labels 
#Step 1: Build a function
def with_words(value, pos):
    millions = int(value/1000000)
   # print(pos)
    return "{} million".format(int(millions))

def with_commas(value, pos):
    return "{:,}".format(int(value))

#Step 2: Use FuncFormatter with that function
formatter = FuncFormatter(with_commas)
ax.set_axisbelow(True)

ax.xaxis.set_major_formatter(formatter)

plt.savefig('Marktwerte.pdf', transparent=True, bbox_inches='tight')
plt.savefig('Marktwerte.png', transparent=True, bbox_inches='tight')

# %%
df_bilanz_new['total-spiel-differenz']
# Out:
# verein
# BSC Young Boys            -1149
# FC Basel                   -481
# FC Lausanne-Sport         -1622
# FC Lugano                  -126
# FC Luzern                  -722
# FC Sion                   -1785
# FC St. Gallen 1879          -18
# FC Thun                     -23
# FC Zürich                 -2060
# Grasshopper Club Zürich    -222
# Name: total-spiel-differenz, dtype: int64

# %% [markdown]
# ## Experience

# %%
fig, ax = plt.subplots(figsize =(15,10))

#Font
csfont = {'fontname':'DIN Condensed'}

df_bilanz_new['total-spiel-differenz'].sort_values(ascending=False).plot(kind='barh', legend=False, ax = ax, color=['#0C2340'])
plt.axes

ax.set_facecolor("#EBEBEB")

ax.set_ylabel('')


#grid
ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey')
#Getting rid of the ax.y
ax.grid(False, axis='y')


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)


#Changing the lims of the bars (from right to left) to (left to right)
plt.xlim([ 0,-2200])


#Ticks
ax.tick_params(left=False)
ax.tick_params(bottom=False)
ax.set_xticks([0, -250, -500, -750, -1000, -1250, -1500, -1750, -2000])
ax.set_xticklabels([0, -250, -500, -750, -1000, -1250, -1500, -1750, "-2000 minutes played"])

#Title
ax.set_title("All Clubs go with Youth over Experience", **csfont, pad=40, fontsize=24)
plt.gcf().text(0.5, 0.9, "Difference in Career Minutes played between the New Players and the ones that left", ha="center", fontsize=14)

#Showing Median
median = df_bilanz_new['total-spiel-differenz'].median()
ax.plot([median, median], [-4, 10], c='darkgrey', linestyle=':')
ax.annotate(s='Median of all clubs', xy=(-610,3.1), color='black')

ax.set_axisbelow(True)
plt.savefig('experience.pdf', transparent=True, bbox_inches='tight')
plt.savefig('experience.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Goals scored

# %%
df_SL_transfers.head()
# Out:
#              Agent Alter                  Ausrüster  Gelb-Rote Karten  \
# 0       Footuro AG    21  Nike Nike Magista Obra II                 0
# 1             ESHA    20                       None                 0
# 2  Sportfront GmbH    24  Nike Nike Magista Obra II                 0
# 6    Gol de Classe    21                       None                 0
# 7  Sportfront GmbH    23                       None                 0
#
#    Gelbe Karten Grösse Im Team seit  Marktwert  \
# 0             3   None   11.01.2018  6000000.0
# 1             6   None   15.01.2018  5000000.0
# 2             6   None   05.07.2018  6500000.0
# 6            25   None   26.02.2018  3000000.0
# 7            13   None   22.06.2018  5000000.0
#
#                              Minuten        Name  \
# 0  <function Minuten at 0x1153ad950>  D. Nikolic
# 1  <function Minuten at 0x1153ad950>   D. Schmid
# 2  <function Minuten at 0x1153ad950>    M. Salvi
# 6  <function Minuten at 0x1153ad950>  P. Pacheco
# 7  <function Minuten at 0x1153ad950>    R. Kapic
#
#                              Position  Rote Karten  Tore  Total Spiele  \
# 0                             Torwart            0     0            45
# 1  Mittelfeld - Offensives Mittelfeld            0    11            84
# 2                             Torwart            0     0           150
# 6           Abwehr - Innenverteidiger            1     3            90
# 7   Mittelfeld - Zentrales Mittelfeld            0    18            84
#
#                                                  URL              Verein  \
# 0  http://www.transfermarkt.ch/djordje-nikolic/pr...             FC Thun
# 1  http://www.transfermarkt.ch/dominik-schmid/pro...   FC Lausanne-Sport
# 2  http://www.transfermarkt.ch/mirko-salvi/profil...           FC Luzern
# 6  http://www.transfermarkt.ch/pedro-pacheco/prof...  FC Rapperswil-Jona
# 7  http://www.transfermarkt.ch/rifet-kapic/profil...    Sheriff Tiraspol
#
#    Vorlagen              Wechsel von            *Wechsel von*  \
# 0         0            FC Basel 1893                 FC Basel
# 1         1            FC Basel 1893                 FC Basel
# 2         0  Grasshopper Club Zürich  Grasshopper Club Zürich
# 6         1            FC Basel 1893                 FC Basel
# 7         5  Grasshopper Club Zürich  Grasshopper Club Zürich
#
#              *Verein*
# 0             FC Thun
# 1   FC Lausanne-Sport
# 2           FC Luzern
# 6  FC Rapperswil-Jona
# 7    Sheriff Tiraspol

# %%
df_SL_transfers['tor_ratio'] = df_SL_transfers.Tore / df_SL_transfers['Total Spiele']
df_SL_transfers.sort_values('tor_ratio', ascending=False).head(10)
# Out:
#                             Agent Alter                         Ausrüster  \
# 266                     Atalentis    20  Nike Nike Hypervenom Phantom III
# 70        Universal Management SA    30                              None
# 46   REAL PRO Football Consultant    19                              None
# 58          Wasserman Netherlands    35                              None
# 396          arena11 sports group    21  Nike Nike Mercurial Superfly 360
# 85        FPA Fairplay Agency Ltd    22
# 207                   LIAN SPORTS    27  Nike Nike Mercurial Superfly 360
# 162                       BSA srl    20                              None
# 112                SOCCER MONDIAL    26  Nike Nike Mercurial Superfly 360
# 83                            SEG    25
#
#      Gelb-Rote Karten  Gelbe Karten Grösse Im Team seit  Marktwert  \
# 266                 1             7   None   01.07.2017  7000000.0
# 70                  2            29   None   01.01.2018  3500000.0
# 46                  0            13   None   01.07.2017  3000000.0
# 58                  2            72   None   06.02.2018  5000000.0
# 396                 0            12   None   30.01.2018  2000000.0
# 85                  0            23   None   01.07.2018  4000000.0
# 207                 2            31   None   31.01.2018  8000000.0
# 162                 0             6   None   25.07.2017  2000000.0
# 112                 1            45   None   01.07.2016        NaN
# 83                  0            49   None   01.07.2018  7500000.0
#
#                                Minuten         Name    ...    Rote Karten  \
# 266  <function Minuten at 0x1153ad950>     A. Pinga    ...              0
# 70   <function Minuten at 0x1153ad950>   S. Doumbia    ...              0
# 46   <function Minuten at 0x1153ad950>    A. Pululu    ...              0
# 58   <function Minuten at 0x1153ad950>     M. Janko    ...              2
# 396  <function Minuten at 0x1153ad950>      M. Koné    ...              0
# 85   <function Minuten at 0x1153ad950>    V. Fazliu    ...              1
# 207  <function Minuten at 0x1153ad950>    A. Sadiku    ...              1
# 162  <function Minuten at 0x1153ad950>  C. Manicone    ...              1
# 112  <function Minuten at 0x1153ad950>    M. Dabbur    ...              0
# 83   <function Minuten at 0x1153ad950>  M. Djuricin    ...              0
#
#      Tore  Total Spiele                                                URL  \
# 266    50            83  http://www.transfermarkt.ch/aimery-pinga/profi...
# 70    194           345  http://www.transfermarkt.ch/seydou-doumbia/pro...
# 46     34            68  http://www.transfermarkt.ch/afimico-pululu/pro...
# 58    213           428  http://www.transfermarkt.ch/marc-janko/profil/...
# 396    34            73  http://www.transfermarkt.ch/moussa-kone/profil...
# 85     55           121  http://www.transfermarkt.ch/valon-fazliu/profi...
# 207   119           263  http://www.transfermarkt.ch/armando-sadiku/pro...
# 162    41            92  http://www.transfermarkt.ch/carlo-manicone/pro...
# 112   114           263  http://www.transfermarkt.ch/munas-dabbur/profi...
# 83    109           252  http://www.transfermarkt.ch/marco-djuricin/pro...
#
#                       Verein Vorlagen     Wechsel von  \
# 266                  FC Sion        2     FC Sion U21
# 70         Sporting Lissabon       61          AS Rom
# 46             FC Basel 1893        3    FC Basel U21
# 58                 FC Lugano       43     Sparta Prag
# 396        SG Dynamo Dresden        8       FC Zürich
# 85                 FC Lugano        9    Grasshoppers
# 207               UD Levante       22  Legia Warschau
# 162                FC Lugano        5      Empoli U19
# 112        Red Bull Salzburg       52    Grasshoppers
# 83   Grasshopper Club Zürich       28     RB Salzburg
#
#                *Wechsel von*                 *Verein* tor_ratio
# 266              FC Sion U21                  FC Sion  0.602410
# 70                    AS Rom        Sporting Lissabon  0.562319
# 46              FC Basel U21                 FC Basel  0.500000
# 58               Sparta Prag                FC Lugano  0.497664
# 396                FC Zürich        SG Dynamo Dresden  0.465753
# 85   Grasshopper Club Zürich                FC Lugano  0.454545
# 207           Legia Warschau               UD Levante  0.452471
# 162               Empoli U19                FC Lugano  0.445652
# 112  Grasshopper Club Zürich        Red Bull Salzburg  0.433460
# 83               RB Salzburg  Grasshopper Club Zürich  0.432540
#
# [10 rows x 21 columns]

# %%
df_SL_transfers.Position
# Out:
# 0                                 Torwart
# 1      Mittelfeld - Offensives Mittelfeld
# 2                                 Torwart
# 6               Abwehr - Innenverteidiger
# 7       Mittelfeld - Zentrales Mittelfeld
# 8       Mittelfeld - Zentrales Mittelfeld
# 9      Mittelfeld - Offensives Mittelfeld
# 11                  Sturm - Mittelstürmer
# 12     Mittelfeld - Defensives Mittelfeld
# 15        Mittelfeld - Rechtes Mittelfeld
# 16                                Torwart
# 17        Mittelfeld - Rechtes Mittelfeld
# 18      Mittelfeld - Zentrales Mittelfeld
# 20      Mittelfeld - Zentrales Mittelfeld
# 21            Abwehr - Linker Verteidiger
# 22                  Sturm - Mittelstürmer
# 24              Abwehr - Innenverteidiger
# 25                  Sturm - Mittelstürmer
# 27        Mittelfeld - Rechtes Mittelfeld
# 28         Mittelfeld - Linkes Mittelfeld
# 32            Abwehr - Linker Verteidiger
# 33     Mittelfeld - Offensives Mittelfeld
# 35                  Sturm - Mittelstürmer
# 36     Mittelfeld - Defensives Mittelfeld
# 37                  Sturm - Mittelstürmer
# 38                  Sturm - Mittelstürmer
# 39     Mittelfeld - Offensives Mittelfeld
# 40              Abwehr - Innenverteidiger
# 41     Mittelfeld - Offensives Mittelfeld
# 42                                Torwart
#                       ...
# 363           Abwehr - Linker Verteidiger
# 364                               Torwart
# 365    Mittelfeld - Defensives Mittelfeld
# 366                               Torwart
# 367                   Sturm - Rechtsaußen
# 368           Abwehr - Linker Verteidiger
# 369                 Sturm - Mittelstürmer
# 370     Mittelfeld - Zentrales Mittelfeld
# 380    Mittelfeld - Defensives Mittelfeld
# 381             Abwehr - Innenverteidiger
# 383    Mittelfeld - Defensives Mittelfeld
# 384                 Sturm - Mittelstürmer
# 385                 Sturm - Mittelstürmer
# 386          Abwehr - Rechter Verteidiger
# 387             Abwehr - Innenverteidiger
# 389        Mittelfeld - Linkes Mittelfeld
# 390                               Torwart
# 391           Abwehr - Linker Verteidiger
# 392                 Sturm - Mittelstürmer
# 393                               Torwart
# 396                 Sturm - Mittelstürmer
# 399    Mittelfeld - Offensives Mittelfeld
# 400          Abwehr - Rechter Verteidiger
# 401             Abwehr - Innenverteidiger
# 402                 Sturm - Mittelstürmer
# 403           Abwehr - Linker Verteidiger
# 404          Abwehr - Rechter Verteidiger
# 408    Mittelfeld - Offensives Mittelfeld
# 409    Mittelfeld - Defensives Mittelfeld
# 410                               Torwart
# Name: Position, Length: 286, dtype: object

# %%
df_SL_transfers.shape
# Out:
# (286, 21)

# %%
goalscorer = df_SL_transfers[df_SL_transfers.Position.str.contains('Sturm' or 'Mittelfeld')]
goalscorer.head()
# Out:
#                  Agent Alter                         Ausrüster  \
# 11                None    22
# 22        ohne Berater    20  Nike Nike Mercurial Superfly 360
# 25  Familienangehörige    22
# 35         Louis Laros    29                              None
# 37                ESHA    21  Nike Nike Mercurial Superfly 360
#
#     Gelb-Rote Karten  Gelbe Karten Grösse Im Team seit  Marktwert  \
# 11                 1             7   None   29.01.2018  2000000.0
# 22                 0            11   None   16.03.2018  4000000.0
# 25                 0            18   None   12.01.2018  2500000.0
# 35                 1            37   None   01.07.2017  3000000.0
# 37                 0            17   None   02.10.2017  5000000.0
#
#                               Minuten                Name    ...     \
# 11  <function Minuten at 0x1153ad950>     Y. Bnou Marzouk    ...
# 22  <function Minuten at 0x1153ad950>            B. Babic    ...
# 25  <function Minuten at 0x1153ad950>         M. Dangubic    ...
# 35  <function Minuten at 0x1153ad950>  R. van Wolfswinkel    ...
# 37  <function Minuten at 0x1153ad950>            A. Ajeti    ...
#
#    Rote Karten  Tore  Total Spiele  \
# 11           0    36           101
# 22           1    40           110
# 25           0    41            96
# 35           0   138           354
# 37           0    64           172
#
#                                                   URL         Verein Vorlagen  \
# 11  http://www.transfermarkt.ch/younes-bnou-marzou...     Dalkurd FF        5
# 22  http://www.transfermarkt.ch/boris-babic/profil...       FC Vaduz        4
# 25  http://www.transfermarkt.ch/marko-dangubic/pro...       FC Köniz        1
# 35  http://www.transfermarkt.ch/ricky-van-wolfswin...  FC Basel 1893       28
# 37  http://www.transfermarkt.ch/albian-ajeti/profi...  FC Basel 1893       16
#
#            Wechsel von            *Wechsel von*    *Verein* tor_ratio
# 11           FC Lugano                FC Lugano  Dalkurd FF  0.356436
# 22  FC St. Gallen 1879  FC St. Gallen 1879 1879    FC Vaduz  0.363636
# 25      BSC Young Boys           BSC Young Boys    FC Köniz  0.427083
# 35     Vitesse Arnheim          Vitesse Arnheim    FC Basel  0.389831
# 37       FC St. Gallen       FC St. Gallen 1879    FC Basel  0.372093
#
# [5 rows x 21 columns]

# %%
goalscorer.sort_values('tor_ratio', ascending=False)
# Out:
#                                                  Agent Alter  \
# 266                                          Atalentis    20
# 70                             Universal Management SA    30
# 46                        REAL PRO Football Consultant    19
# 58                               Wasserman Netherlands    35
# 396                               arena11 sports group    21
# 207                                        LIAN SPORTS    27
# 162                                            BSA srl    20
# 112                                     SOCCER MONDIAL    26
# 83                                                 SEG    25
# 25                                  Familienangehörige    22
# 345                                               None    21
# 229                                               None    23
# 44                                 AR Sport Management    24
# 35                                         Louis Laros    29
# 211                            Go Pro Sport Management    21
# 73                                      SOCCER MONDIAL    24
# 353                                      Sport Profile    25
# 354                                                 3A    24
# 205                        Palomba Sportmanagement&CDR    24
# 37                                                ESHA    21
# 89                                  Familienangehörige    23
# 22                                        ohne Berater    20
# 11                                                None    22
# 49                                      SOCCER MONDIAL    21
# 224                                            teambbc    19
# 242                                     SOCCER MONDIAL    33
# 92                                      SOCCER MONDIAL    24
# 38                                      SOCCER MONDIAL    20
# 273                             Extra Time Sports U.K.    25
# 385                                 Familienangehörige    21
# ..                                                 ...   ...
# 51                                                 IFM    22
# 114                                               None    25
# 284                      Altis Sportconsulting Company    28
# 117                           Global Management Agency    32
# 115                                    Reset Group Srl    25
# 259                                     Adequatesports    22
# 254                                               None    30
# 165                                               None    19
# 304                                               None    18
# 50                                Stellar Football Ltd    24
# 139                                       Gold Kick SA    26
# 209                                               None    23
# 187                                    Prestige Sports    24
# 78                                          Mela Kodro    24
# 367                                     score agencies    28
# 243                                         Soccerdome    22
# 351                               TJP-Sport-Management    24
# 125                                  Five Stars Sports    33
# 274                                    Stars & Friends    29
# 192                                 Top Sport Services    24
# 137                                               None    26
# 392  MÜLLER & PAPARIS  RECHTSANWÄLTE / ATTORNEYS AT...    22
# 167                                    Sportfront GmbH    22
# 384                                         Nadir Kama    20
# 191                                          HBR Sport    26
# 87                                      SOCCER MONDIAL    20
# 74                                   Media Base Sports    30
# 156                          GBG Global Business Group    22
# 216                                         Soccerdome    25
# 94                                       Ansaro Agency    22
#
#                             Ausrüster  Gelb-Rote Karten  Gelbe Karten Grösse  \
# 266  Nike Nike Hypervenom Phantom III                 1             7   None
# 70                               None                 2            29   None
# 46                               None                 0            13   None
# 58                               None                 2            72   None
# 396  Nike Nike Mercurial Superfly 360                 0            12   None
# 207  Nike Nike Mercurial Superfly 360                 2            31   None
# 162                              None                 0             6   None
# 112  Nike Nike Mercurial Superfly 360                 1            45   None
# 83                                                    0            49   None
# 25                                                    0            18   None
# 345                              None                 0             8   None
# 229                              None                 0            15   None
# 44   Nike Nike Mercurial Superfly 360                 0            20   None
# 35                               None                 1            37   None
# 211                              None                 0             4   None
# 73                               None                 1            19   None
# 353                              None                 0             8   None
# 354     Nike Nike Mercurial Vapor 360                 0            10   None
# 205                              None                 3             9   None
# 37   Nike Nike Mercurial Superfly 360                 0            17   None
# 89   Nike Nike Mercurial Superfly 360                 0            13   None
# 22   Nike Nike Mercurial Superfly 360                 0            11   None
# 11                                                    1             7   None
# 49      Nike Nike Mercurial Vapor 360                 1            23   None
# 224                              None                 0             7   None
# 242                                                   1            53   None
# 92                               None                 1            16   None
# 38   Nike Nike Hypervenom Phantom III                 0            11   None
# 273  Nike Nike Hypervenom Phantom III                 0            42   None
# 385     Nike Nike Mercurial Vapor 360                 0             4   None
# ..                                ...               ...           ...    ...
# 51   Nike Nike Mercurial Superfly 360                 0             5   None
# 114                              None                 3            34   None
# 284                              None                 0            20   None
# 117                              None                 0            37   None
# 115                              None                 0            16   None
# 259                              None                 0            14   None
# 254                              None                 0            20   None
# 165                              None                 0            10   None
# 304     Nike Nike Mercurial Vapor 360                 0             0   None
# 50                               None                 0            15   None
# 139         Nike Nike Magista Obra II                 1            42   None
# 209                              None                 0            19   None
# 187                                                   0             6   None
# 78      Nike Nike Mercurial Vapor 360                 0            19   None
# 367     Nike Nike Mercurial Vapor 360                 0            20   None
# 243                              None                 0             8   None
# 351                                                   1            10   None
# 125                              None                 1            41   None
# 274                              None                 0            19   None
# 192                              None                 0            23   None
# 137                              None                 1            24   None
# 392                              None                 0            11   None
# 167                              None                 0             5   None
# 384                                                   0             1   None
# 191                              None                 0            10   None
# 87   Nike Nike Mercurial Superfly 360                 0            10   None
# 74                               None                 0            14   None
# 156                              None                 0             5   None
# 216                              None                 0             1   None
# 94                               None                 0             2   None
#
#     Im Team seit  Marktwert                            Minuten  \
# 266   01.07.2017  7000000.0  <function Minuten at 0x1153ad950>
# 70    01.01.2018  3500000.0  <function Minuten at 0x1153ad950>
# 46    01.07.2017  3000000.0  <function Minuten at 0x1153ad950>
# 58    06.02.2018  5000000.0  <function Minuten at 0x1153ad950>
# 396   30.01.2018  2000000.0  <function Minuten at 0x1153ad950>
# 207   31.01.2018  8000000.0  <function Minuten at 0x1153ad950>
# 162   25.07.2017  2000000.0  <function Minuten at 0x1153ad950>
#
07.2018  4000000.0  <function Minuten at 0x1153ad950>
# 384   04.10.2017  4000000.0  <function Minuten at 0x1153ad950>
# 191   12.01.2018  4000000.0  <function Minuten at 0x1153ad950>
# 87    29.01.2018  5000000.0  <function Minuten at 0x1153ad950>
# 74    09.07.2017  1000000.0  <function Minuten at 0x1153ad950>
# 156   17.07.2018  2500000.0  <function Minuten at 0x1153ad950>
# 216   01.07.2018  3000000.0  <function Minuten at 0x1153ad950>
# 94             -  4000000.0  <function Minuten at 0x1153ad950>
#
#                    Name    ...    Rote Karten  Tore  Total Spiele  \
# 266            A. Pinga    ...              0    50            83
# 70           S. Doumbia    ...              0   194           345
# 46            A. Pululu    ...              0    34            68
# 58             M. Janko    ...              2   213           428
# 396             M. Koné    ...              0    34            73
# 207           A. Sadiku    ...              1   119           263
# 162         C. Manicone    ...              1    41            92
# 112           M. Dabbur    ...              0   114           263
# 83          M. Djuricin    ...              0   109           252
# 25          M. Dangubic    ...              0    41            96
# 345         I. Markovic    ...              0    36            85
# 229            O. Thali    ...              0    43           104
# 44            A. Sporar    ...              0    77           187
# 35   R. van Wolfswinkel    ...              0   138           354
# 211            A. Ponce    ...              0    30            78
# 73           A. Avdijaj    ...              0    72           188
# 353            J. Nsame    ...              0    40           105
# 354           R. Assalé    ...              1    35            92
# 205           A. Ceesay    ...              0    22            59
# 37             A. Ajeti    ...              0    64           172
# 89           F. Kamberi    ...              0    41           112
# 22             B. Babic    ...              1    40           110
# 11      Y. Bnou Marzouk    ...              0    36           101
# 49          N. Manzambi    ...              0    43           124
# 224           R. Vargas    ...              0    19            55
# 242        M. Schneuwly    ...              2   161           467
# 92         H. Tabakovic    ...              1    52           151
# 38           D. Oberlin    ...              1    44           130
# 273           M. Konaté    ...              2    75           227
# 385         K. Pagliuca    ...              0    20            61
# ..                  ...    ...            ...   ...           ...
# 51          N. Hunziker    ...              0    28           108
# 114             S. Rapp    ...              0    64           249
# 284              G. Bia    ...              0    69           270
# 117          V. Bojinov    ...              1   101           403
# 115        F. Margiotta    ...              0    42           171
# 259           A. Succar    ...              0    21            91
# 254      R. Acquafresca    ...              0    67           303
# 165         G. Franzese    ...              1     9            41
# 304         N. Blasucci    ...              0    14            66
# 50           J. Boëtius    ...              0    40           193
# 139      N. Ben Khalifa    ...              1    50           243
# 209          L. Rosseti    ...              3    31           154
# 187            K. Rossi    ...              0    17            85
# 78             K. Kodro    ...              0    38           191
# 367            Y. Ravet    ...              1    52           262
# 243         J. Oliveira    ...              0    24           125
# 351   N. Moumi Ngamaleu    ...              0    15            84
# 125           G. Zárate    ...              3    67           377
# 274       Léo Itaperuna    ...              0    33           190
# 192          O. Mizrahi    ...              0    26           151
# 137         J. Esnáider    ...              0    20           117
# 392             M. Graf    ...              0    16            95
# 167           A. Padula    ...              0    16           100
# 384             S. Odey    ...              0     3            19
# 191           A. Culina    ...              1    23           166
# 87           N. Sukacev    ...              1     7            58
# 74              Jeffren    ...              0    22           205
# 156           K. Méndez    ...              0     6            58
# 216             I. Jong    ...              0     1            12
# 94            G. Sherko    ...              0     3            38
#
#                                                    URL  \
# 266  http://www.transfermarkt.ch/aimery-pinga/profi...
# 70   http://www.transfermarkt.ch/seydou-doumbia/pro...
# 167                FC Lugano                   FC Chiasso  0.160000
# 384                   MFM FC                    FC Zürich  0.157895
# 191                FC Lugano              Cracovia Krakau  0.138554
# 87             GC Zürich U21      Grasshopper Club Zürich  0.120690
# 74                 KAS Eupen      Grasshopper Club Zürich  0.107317
# 156              Rom Weitere                 Karpaty Lviv  0.103448
# 216                FC Luzern                   Vereinslos  0.083333
# 94                  FC Vaduz  Grasshopper Club Zürich U21  0.078947
#
# [76 rows x 21 columns]

# %%
goalscorer.sort_values('tor_ratio', ascending=False)
# Out:
#                                                  Agent Alter  \
# 266                                          Atalentis    20
# 70                             Universal Management SA    30
# 46                        REAL PRO Football Consultant    19
# 58                               Wasserman Netherlands    35
# 396                               arena11 sports group    21
# 207                                        LIAN SPORTS    27
# 162                                            BSA srl    20
# 112                                     SOCCER MONDIAL    26
# 83                                                 SEG    25
# 25                                  Familienangehörige    22
# 345                                               None    21
# 229                                               None    23
# 44                                 AR Sport Management    24
# 35                                         Louis Laros    29
# 211                            Go Pro Sport Management    21
# 73                                      SOCCER MONDIAL    24
# 353                                      Sport Profile    25
# 354                                                 3A    24
# 205                        Palomba Sportmanagement&CDR    24
# 37                                                ESHA    21
# 89                                  Familienangehörige    23
# 22                                        ohne Berater    20
# 11                                                None    22
# 49                                      SOCCER MONDIAL    21
# 224                                            teambbc    19
# 242                                     SOCCER MONDIAL    33
# 92                                      SOCCER MONDIAL    24
# 38                                      SOCCER MONDIAL    20
# 273                             Extra Time Sports U.K.    25
# 385                                 Familienangehörige    21
# ..                                                 ...   ...
# 51                                                 IFM    22
# 114                                               None    25
# 284                      Altis Sportconsulting Company    28
# 117                           Global Management Agency    32
# 115                                    Reset Group Srl    25
# 259                                     Adequatesports    22
# 254                                               None    30
# 165                                               None    19
# 304                                               None    18
# 50                                Stellar Football Ltd    24
# 139                                       Gold Kick SA    26
# 209                                               None    23
# 187                                    Prestige Sports    24
# 78                                          Mela Kodro    24
# 367                                     score agencies    28
# 243                                         Soccerdome    22
# 351                               TJP-Sport-Management    24
# 125                                  Five Stars Sports    33
# 274                                    Stars & Friends    29
# 192                                 Top Sport Services    24
# 137                                               None    26
# 392  MÜLLER & PAPARIS  RECHTSANWÄLTE / ATTORNEYS AT...    22
# 167                                    Sportfront GmbH    22
# 384                                         Nadir Kama    20
# 191                                          HBR Sport    26
# 87                                      SOCCER MONDIAL    20
# 74                                   Media Base Sports    30
# 156                          GBG Global Business Group    22
# 216                                         Soccerdome    25
# 94                                       Ansaro Agency    22
#
#                             Ausrüster  Gelb-Rote Karten  Gelbe Karten Grösse  \
# 266  Nike Nike Hypervenom Phantom III                 1             7   None
# 70                               None                 2            29   None
# 46                               None                 0            13   None
# 58                               None                 2            72   None
# 396  Nike Nike Mercurial Superfly 360                 0            12   None
# 207  Nike Nike Mercurial Superfly 360                 2            31   None
# 162                              None                 0             6   None
# 112  Nike Nike Mercurial Superfly 360                 1            45   None
# 83                                                    0            49   None
# 25                                                    0            18   None
# 345                              None                 0             8   None
# 229                              None                 0            15   None
# 44   Nike Nike Mercurial Superfly 360                 0            20   None
# 35                               None                 1            37   None
# 211                              None                 0             4   None
# 73                               None                 1            19   None
# 353                              None                 0             8   None
# 354     Nike Nike Mercurial Vapor 360                 0            10   None
# 205                              None                 3             9   None
# 37   Nike Nike Mercurial Superfly 360                 0            17   None
# 89   Nike Nike Mercurial Superfly 360                 0            13   None
# 22   Nike Nike Mercurial Superfly 360                 0            11   None
# 11                                                    1             7   None
# 49      Nike Nike Mercurial Vapor 360                 1            23   None
# 224                              None                 0             7   None
# 242                                                   1            53   None
# 92                               None                 1            16   None
# 38   Nike Nike Hypervenom Phantom III                 0            11   None
# 273  Nike Nike Hypervenom Phantom III                 0            42   None
# 385     Nike Nike Mercurial Vapor 360                 0             4   None
# ..                                ...               ...           ...    ...
# 51   Nike Nike Mercurial Superfly 360                 0             5   None
# 114                              None                 3            34   None
# 284                              None                 0            20   None
# 117                              None                 0            37   None
# 115                              None                 0            16   None
# 259                              None                 0            14   None
# 254                              None                 0            20   None
# 165                              None                 0            10   None
# 304     Nike Nike Mercurial Vapor 360                 0             0   None
# 50                               None                 0            15   None
# 139         Nike Nike Magista Obra II                 1            42   None
# 209                              None                 0            19   None
# 187                                                   0             6   None
# 78      Nike Nike Mercurial Vapor 360                 0            19   None
# 367     Nike Nike Mercurial Vapor 360                 0            20   None
# 243                              None                 0             8   None
# 351                                                   1            10   None
# 125                              None                 1            41   None
# 274                              None                 0            19   None
# 192                              None                 0            23   None
# 137                              None                 1            24   None
# 392                              None                 0            11   None
# 167                              None                 0             5   None
# 384                                                   0             1   None
# 191                              None                 0            10   None
# 87   Nike Nike Mercurial Superfly 360                 0            10   None
# 74                               None                 0            14   None
# 156                              None                 0             5   None
# 216                              None                 0             1   None
# 94                               None                 0             2   None
#
#     Im Team seit  Marktwert                            Minuten  \
# 266   01.07.2017  7000000.0  <function Minuten at 0x1153ad950>
# 70    01.01.2018  3500000.0  <function Minuten at 0x1153ad950>
# 46    01.07.2017  3000000.0  <function Minuten at 0x1153ad950>
# 58    06.02.2018  5000000.0  <function Minuten at 0x1153ad950>
# 396   30.01.2018  2000000.0  <function Minuten at 0x1153ad950>
# 207   31.01.2018  8000000.0  <function Minuten at 0x1153ad950>
# 162   25.07.2017  2000000.0  <function Minuten at 0x1153ad950>
# 112   01.07.2016        NaN  <function Minuten at 0x1153ad950>
# 83    01.07.2018  7500000.0  <function Minuten at 0x1153ad950>
# 25    12.01.2018  2500000.0  <function Minuten at 0x1153ad950>
# 345   01.07.2018  1000000.0  <function Minuten at 0x1153ad950>
# 229   01.05.2018  1500000.0  <function Minuten at 0x1153ad950>
# 44    03.01.2018  7500000.0  <function Minuten at 0x1153ad950>
# 35    01.07.2017  3000000.0  <function Minuten at 0x1153ad950>
# 211            -  3000000.0  <function Minuten at 0x1153ad950>
# 73    01.07.2018  4000000.0  <function Minuten at 0x1153ad950>
# 353   19.07.2017  4500000.0  <function Minuten at 0x1153ad950>
# 354   01.07.2017  7500000.0  <function Minuten at 0x1153ad950>
# 205   01.07.2016  7000000.0  <function Minuten at 0x1153ad950>
# 37    02.10.2017  5000000.0  <function Minuten at 0x1153ad950>
# 89    01.07.2018  5000000.0  <function Minuten at 0x1153ad950>
# 22    16.03.2018  4000000.0  <function Minuten at 0x1153ad950>
# 11    29.01.2018  2000000.0  <function Minuten at 0x1153ad950>
# 49    01.07.2017  5000000.0  <function Minuten at 0x1153ad950>
# 224   01.07.2017  1000000.0  <function Minuten at 0x1153ad950>
# 242   02.07.2018  6000000.0  <function Minuten at 0x1153ad950>
# 92    04.08.2017  3500000.0  <function Minuten at 0x1153ad950>
# 38    01.07.2018  6000000.0  <function Minuten at 0x1153ad950>
# 273   13.08.2017        NaN  <function Minuten at 0x1153ad950>
# 385   01.07.2018  3500000.0  <function Minuten at 0x1153ad950>
# ..           ...        ...                                ...
# 51    01.07.2017  6000000.0  <function Minuten at 0x1153ad950>
# 114   04.01.2018  1500000.0  <function Minuten at 0x1153ad950>
# 284   01.07.2018  4000000.0  <function Minuten at 0x1153ad950>
# 117   07.02.2018  3000000.0  <function Minuten at 0x1153ad950>
# 115   31.01.2018  1750000.0  <function Minuten at 0x1153ad950>
# 259   01.01.2014  4500000.0  <function Minuten at 0x1153ad950>
# 254   01.07.2018  3000000.0  <function Minuten at 0x1153ad950>
# 165   01.01.2017  1000000.0  <function Minuten at 0x1153ad950>
# 304   01.07.2017  1000000.0  <function Minuten at 0x1153ad950>
# 50    01.07.2017  2000000.0  <function Minuten at 0x1153ad950>
# 139   01.07.2017  1000000.0  <function Minuten at 0x1153ad950>
# 209   18.08.2017  5500000.0  <function Minuten at 0x1153ad950>
# 187   25.08.2017  1500000.0  <function Minuten at 0x1153ad950>
# 78    03.07.2018  2000000.0  <function Minuten at 0x1153ad950>
# 367   26.08.2017  3000000.0  <function Minuten at 0x1153ad950>
# 243   01.07.2018  5000000.0  <function Minuten at 0x1153ad950>
# 351   26.08.2017  2500000.0  <function Minuten at 0x1153ad950>
# 125   01.07.2018  2500000.0  <function Minuten at 0x1153ad950>
# 274   27.03.2018  5000000.0  <function Minuten at 0x1153ad950>
# 192   01.07.2017  5000000.0  <function Minuten at 0x1153ad950>
# 137   01.07.2018  1000000.0  <function Minuten at 0x1153ad950>
# 392   01.07.2017  2000000.0  <function Minuten at 0x1153ad950>
# 167   09.07.2018  4000000.0  <function Minuten at 0x1153ad950>
# 384   04.10.2017  4000000.0  <function Minuten at 0x1153ad950>
# 191   12.01.2018  4000000.0  <function Minuten at 0x1153ad950>
# 87    29.01.2018  5000000.0  <function Minuten at 0x1153ad950>
# 74    09.07.2017  1000000.0  <function Minuten at 0x1153ad950>
# 156   17.07.2018  2500000.0  <function Minuten at 0x1153ad950>
# 216   01.07.2018  3000000.0  <function Minuten at 0x1153ad950>
# 94             -  4000000.0  <function Minuten at 0x1153ad950>
#
#                    Name    ...    Rote Karten  Tore  Total Spiele  \
# 266            A. Pinga    ...              0    50            83
# 70           S. Doumbia    ...              0   194           345
# 46            A. Pululu    ...              0    34            68
# 58             M. Janko    ...              2   213           428
# 396             M. Koné    ...              0    34            73
# 207           A. Sadiku    ...              1   119           263
# 162         C. Manicone    ...              1    41            92
# 112           M. Dabbur    ...              0   114           263
# 83          M. Djuricin    ...              0   109           252
# 25          M. Dangubic    ...              0    41            96
# 345         I. Markovic    ...              0    36            85
# 229            O. Thali    ...              0    43           104
# 44            A. Sporar    ...              0    77           187
# 35   R. van Wolfswinkel    ...              0   138           354
# 211            A. Ponce    ...              0    30            78
# 73           A. Avdijaj    ...              0    72           188
# 353            J. Nsame    ...              0    40           105
# 354           R. Assalé    ...              1    35            92
# 205           A. Ceesay    ...              0    22            59
# 37             A. Ajeti    ...              0    64           172
# 89           F. Kamberi    ...              0    41           112
# 22             B. Babic    ...              1    40           110
# 11      Y. Bnou Marzouk    ...              0    36           101
# 49          N. Manzambi    ...              0    43           124
# 224           R. Vargas    ...              0    19            55
# 242        M. Schneuwly    ...              2   161           467
# 92         H. Tabakovic    ...              1    52           151
# 38           D. Oberlin    ...              1    44           130
# 273           M. Konaté    ...              2    75           227
# 385         K. Pagliuca    ...              0    20            61
# ..                  ...    ...            ...   ...           ...
# 51          N. Hunziker    ...              0    28           108
# 114             S. Rapp    ...              0    64           249
# 284              G. Bia    ...              0    69           270
# 117          V. Bojinov    ...              1   101           403
# 115        F. Margiotta    ...              0    42           171
# 259           A. Succar    ...              0    21            91
# 254      R. Acquafresca    ...              0    67           303
# 165         G. Franzese    ...              1     9            41
# 304         N. Blasucci    ...              0    14            66
# 50           J. Boëtius    ...              0    40           193
# 139      N. Ben Khalifa    ...              1    50           243
# 209          L. Rosseti    ...              3    31           154
# 187            K. Rossi    ...              0    17            85
# 78             K. Kodro    ...              0    38           191
# 367            Y. Ravet    ...              1    52           262
# 243         J. Oliveira    ...              0    24           125
# 351   N. Moumi Ngamaleu    ...              0    15            84
# 125           G. Zárate    ...              3    67           377
# 274       Léo Itaperuna    ...              0    33           190
# 192          O. Mizrahi    ...              0    26           151
# 137         J. Esnáider    ...              0    20           117
# 392             M. Graf    ...              0    16            95
# 167           A. Padula    ...              0    16           100
# 384             S. Odey    ...              0     3            19
# 191           A. Culina    ...              1    23           166
# 87           N. Sukacev    ...              1     7            58
# 74              Jeffren    ...              0    22           205
# 156           K. Méndez    ...              0     6            58
# 216             I. Jong    ...              0     1            12
# 94            G. Sherko    ...              0     3            38
#
#                                                    URL  \
# 266  http://www.transfermarkt.ch/aimery-pinga/profi...
# 70   http://www.transfermarkt.ch/seydou-doumbia/pro...
# 46   http://www.transfermarkt.ch/afimico-pululu/pro...
# 58   http://www.transfermarkt.ch/marc-janko/profil/...
# 396  http://www.transfermarkt.ch/moussa-kone/profil...
# 207  http://www.transfermarkt.ch/armando-sadiku/pro...
# 162  http://www.transfermarkt.ch/carlo-manicone/pro...
# 112  http://www.transfermarkt.ch/munas-dabbur/profi...
# 83   http://www.transfermarkt.ch/marco-djuricin/pro...
# 25   http://www.transfermarkt.ch/marko-dangubic/pro...
# 345  http://www.transfermarkt.ch/ivan-markovic/prof...
# 229  http://www.transfermarkt.ch/omar-thali/profil/...
# 44   http://www.transfermarkt.ch/andraz-sporar/prof...
# 35   http://www.transfermarkt.ch/ricky-van-wolfswin...
# 211  http://www.transfermarkt.ch/andres-ponce/profi...
# 73   http://www.transfermarkt.ch/albion-avdijaj/pro...
# 353  http://www.transfermarkt.ch/jean-pierre-nsame/...
# 354  http://www.transfermarkt.ch/roger-assale/profi...
# 205  http://www.transfermarkt.ch/assan-ceesay/profi...
# 211              Feralpisalò      Sampdoria Genua Weitere  0.384615
# 73   Grasshopper Club Zürich                   Vereinslos  0.382979
# 353              Servette FC               BSC Young Boys  0.380952
# 354               TP Mazembe               BSC Young Boys  0.380435
# 205               FC Chiasso                    FC Lugano  0.372881
# 37        FC St. Gallen 1879                     FC Basel  0.372093
# 89   Grasshopper Club Zürich                 Hibernian FC  0.366071
# 22   FC St. Gallen 1879 1879                     FC Vaduz  0.363636
# 11                 FC Lugano                   Dalkurd FF  0.356436
# 49              FC Basel U21                     FC Basel  0.346774
# 224               Luzern U21                    FC Luzern  0.345455
# 242                  FC Sion                     FC Aarau  0.344754
# 92   Grasshopper Club Zürich                Debreceni VSC  0.344371
# 38               RB Salzburg                     FC Basel  0.338462
# 273                  FC Sion                    SC Amiens  0.330396
# 385                FC Zürich                FC Zürich U21  0.327869
# ..                       ...                          ...       ...
# 51                  FC Basel                      FC Thun  0.259259
# 114                  FC Thun            FC Lausanne-Sport  0.257028
# 284              Kayserispor                   Vereinslos  0.255556
# 117               Vereinslos                   HNK Rijeka  0.250620
# 115           Juventus Turin            FC Lausanne-Sport  0.245614
# 259                  FC Sion        Sporting Cristal Lima  0.230769
# 254                  FC Sion                   Vereinslos  0.221122
# 165            United Zürich                    FC Lugano  0.219512
# 304           St. Gallen U21           FC St. Gallen 1879  0.212121
# 50                  FC Basel          Feyenoord Rotterdam  0.207254
# 139        FC Lausanne-Sport           FC St. Gallen 1879  0.205761
# 209           Juventus Turin               Ascoli Picchio  0.201299
# 187                FC Lugano        SC Cambuur-Leeuwarden  0.200000
# 78            1.FSV Mainz 05                FC Kopenhagen  0.198953
# 367           BSC Young Boys                  SC Freiburg  0.198473
# 243                FC Luzern            FC Lausanne-Sport  0.192000
# 351               SCR Altach               BSC Young Boys  0.178571
# 125        FC Lausanne-Sport                   Vereinslos  0.177719
# 274           São Bento (SP)                 Paraná Clube  0.173684
# 192                FC Lugano                Maccabi Haifa  0.172185
# 137              CD Tudelano                   Vereinslos  0.170940
# 392                FC Zürich                FC Zürich U21  0.168421
# 167                FC Lugano                   FC Chiasso  0.160000
# 384                   MFM FC                    FC Zürich  0.157895
# 191                FC Lugano              Cracovia Krakau  0.138554
# 87             GC Zürich U21      Grasshopper Club Zürich  0.120690
# 74                 KAS Eupen      Grasshopper Club Zürich  0.107317
# 156              Rom Weitere                 Karpaty Lviv  0.103448
# 216                FC Luzern                   Vereinslos  0.083333
# 94                  FC Vaduz  Grasshopper Club Zürich U21  0.078947
#
# [76 rows x 21 columns]

# %%
fig, ax = plt.subplots(figsize =(15,10))

#Font
csfont = {'fontname':'DIN Condensed'}

goalscorer.plot(x='Marktwert', y='tor_ratio', kind='scatter', ax = ax, color=['#0C2340'])
plt.axes

ax.set_facecolor("#EBEBEB")

#Formatting x-labels 
#Step 1: Build a function
def with_words(value, pos):
    millions = int(value/1000000)
   # print(pos)
    return "{} million".format(int(millions))

def with_commas(value, pos):
    return "{:,}".format(int(value))

#Step 2: Use FuncFormatter with that function
formatter = FuncFormatter(with_commas)
ax.set_axisbelow(True)

ax.xaxis.set_major_formatter(formatter)
