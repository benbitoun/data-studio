# %%
import pandas as pd
import numpy as np

# %%
# Identifier (Identifier der Ressource im Quellsystem des Publishers): Traktanden_SR_2018_bis_Heute_CSV
# Titel (Titel der Datei): Traktanden_SR_2018 bis heute mit Beschlüssen
# Beschreibung (Datei-Informationen): Die Traktandenliste aller Geschäfte und Beschlüsse zu den Stadtratssitzungen der Stadt Bern.
# Sprache (Sprache in der diese Datei vorliegt): Deutsch
# Erstellt (Datum der Veröffentlichung dieser Datei): 01.12.2017
# Geändert (Datum der letzten Änderung dieser Datei): 01.12.2017
# Nutzungsbedingungen (Art der Nutzung und Angabepflicht): Freie Nutzung - Quellenangben ist Pflicht (Autor, Titel und Link zum Datensatz).
# Zugangs-URL (Die URL über welche auf die Ressource zugegriffen werden kann): http://www.bern.ch/open-government-data-ogd/ogd-nach-themen/stadtrat-ogd
# Download-URL (URL der Datei um die Ressource direkt heruntergeladen werden kann): http://www.bern.ch/open-government-data-ogd/ogd-nach-themen/stadtrat-ogd/download-stadtraetische-traktanden-und-beschluesse-ogd/traktanden-sr-2018-bis-heute-mit-beschlussen.txt/download
# Dateigrösse (Angabe in Bytes): 46157
# Dateiformat (Datei Typ und Kürzel des Formats): CSV
# Autor der Datei (Ein oder mehrere Autoren dieser Datei): Ratssekretariat des Stadtrats der Stadt Bern
# Dateibezogene Zusatzinformationen (Der richtige Umgang und Interpretation die es ggf. zu berücksichtigen gilt.): Weitere Informationen zu den einzelnen Traktanden und Geschäfte finden Sie als PDF Datei unter http://www.bern.ch/politik-und-verwaltung/stadtrat/sitzung-geschaeft.

# %%
df = pd.read_csv("traktanden_sr_2018.csv", delimiter=";", encoding="Latin 1")
df.head(25)
# Out:
#     Traktanden Nr.                               Traktandierungstitel  \
# 0                1  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...
# 1               19  Dringliche interfraktionelle Motion FDP/JF, BD...
# 2               20  Motion Fraktion SVP (Alexander Feuz, SVP): Vel...
# 3               21  Motion Fraktion SP (Michael Sutter/David Stamp...
# 4               22  Postulat Fraktion SVP (Hans Ulrich Gränicher/A...
# 5               23  Interpellation Fraktion SVP (Alexander Feuz/Ha...
# 6               24  Interpellation Fraktion SVP (Rudolf Friedli, S...
# 7                1  Protokollgenehmigung Stadtrat 2018 (Protokoll ...
# 8                2               Aufsichtskommission (AK): Ersatzwahl
# 9                3  Kommission für Finanzen, Sicherheit und Umwelt...
# 10               4         Agglomerationskommission (AKO): Ersatzwahl
# 11               5  BERNMOBIL: Ersatzwahl Verwaltungsrat für die A...
# 12               6  Kleine Anfrage Barbara Freiburghaus (FDP): Ver...
# 13               7  Kleine Anfrage Fraktion GB/JA! (Ursina Andereg...
# 14               8                                 Jahresbericht 2017
# 15               9  Dringliche interfraktionelle Motion FDP/JF, BD...
# 16              10  Sanierung Thunstrasse West Projektierungskredi...
# 17              11  Verkehrsberuhigung Brunnadern-Elfenau Projekti...
# 18              12  Dringliche Motion Fraktion GB/JA! (Rahel Ruch,...
# 19              13  Postulat Fraktion SP (Benno Frauchiger/Martin ...
# 20              14  Bericht über die Verwaltungskontrollarbeit der...
# 21              15  Tätigkeitsbericht der Ombuds- und der Datenauf...
# 22              16                     Wasserstrategie der Stadt Bern
# 23               1  Dringliches interfraktionelles Postulat BDP/CV...
# 24               1  Dringliche Motion Fraktion FDP/JF (Bernhard Ei...
#
#    Beschluss Nr. Traktandumstatus                              Beschluss  \
# 0            NaN     Traktandiert                                    NaN
# 1       2018-321      Beschlossen                           Verschiebung
# 2       2018-322      Beschlossen                           Verschiebung
# 3       2018-323      Beschlossen                           Verschiebung
# 4       2018-324      Beschlossen                           Verschiebung
# 5       2018-325      Beschlossen                           Verschiebung
# 6       2018-326      Beschlossen                           Verschiebung
# 7       2018-327      Beschlossen                            Genehmigung
# 8       2018-328      Beschlossen                                   Wahl
# 9       2018-329      Beschlossen                                   Wahl
# 10      2018-330      Beschlossen                                   Wahl
# 11      2018-331      Beschlossen                                   Wahl
# 12      2018-332      Beschlossen                               Kenntnis
# 13      2018-333      Beschlossen                               Kenntnis
# 14      2018-334      Beschlossen                               Kenntnis
# 15      2018-335      Beschlossen  Teilweise Erheblicherkl. als Postulat
# 16      2018-336      Beschlossen                            Bewilligung
# 17      2018-337      Beschlossen                            Bewilligung
# 18      2018-338      Beschlossen                           Verschiebung
# 19      2018-339      Beschlossen                           Verschiebung
# 20      2018-340      Beschlossen                           Verschiebung
# 21      2018-341      Beschlossen                           Verschiebung
# 22      2018-342      Beschlossen                           Verschiebung
# 23           NaN     Traktandiert                                    NaN
# 24           NaN     Traktandiert                                    NaN
#
#          Datum
# 0   14.06.2018
# 1   14.06.2018
# 2   14.06.2018
# 3   14.06.2018
# 4   14.06.2018
# 5   14.06.2018
# 6   14.06.2018
# 7   28.06.2018
# 8   28.06.2018
# 9   28.06.2018
# 10  28.06.2018
# 11  28.06.2018
# 12  28.06.2018
# 13  28.06.2018
# 14  28.06.2018
# 15  28.06.2018
# 16  28.06.2018
# 17  28.06.2018
# 18  28.06.2018
# 19  28.06.2018
# 20  28.06.2018
# 21  28.06.2018
# 22  28.06.2018
# 23  31.05.2018
# 24  17.05.2018

# %%
df.shape
# Out:
# (242, 6)

# %%
df.dtypes
# Out:
# Traktanden Nr.           int64
# Traktandierungstitel    object
# Beschluss Nr.           object
# Traktandumstatus        object
# Beschluss               object
# Datum                   object
# dtype: object

# %%
len(df.Traktandierungstitel.value_counts())
# Out:
# 200

# %%
df.Beschluss.value_counts()
# Out:
# Verschiebung                             64
# Kenntnis                                 41
# Ablehnung                                19
# Wahl                                     13
# Bewilligung                               9
# Erheblicherkl.                            8
# Genehmigung                               7
# Erheblicherkl. als Richtlinie             5
# Genehmigung Prüf.bericht                  4
# Fristverl.                                3
# Abschreibung                              2
# Erheblicherkl. als Postulat               2
# Rückzug                                   2
# Teilweise Erheblicherkl. als Postulat     2
# Verabschiedung zuhanden 2. Lesung         1
# Teilweise Erheblicherkl.                  1
# Name: Beschluss, dtype: int64

# %%
df.Datum.dtype
# Out:
# dtype('O')

# %%
#Changing to datetime:
df.Datum.head()
# Out:
# 0    14.06.2018
# 1    14.06.2018
# 2    14.06.2018
# 3    14.06.2018
# 4    14.06.2018
# Name: Datum, dtype: object

# %%
pd.to_datetime(df['Datum'], format="%d.%m.%Y")
#Save into new colum:
df['datum'] = pd.to_datetime(df['Datum'], format="%d.%m.%Y")
df.tail(50)
# Out:
#      Traktanden Nr.                               Traktandierungstitel  \
# 192              16  Interpellation Fraktion FDP (Bernhard Eicher, ...
# 193              17  Motion Luzius Theiler (GPB-DA): Besserer Recht...
# 194              18  Postulat Fraktion SP (Katharina Altas/Halua Pi...
# 195              19  Motion Fraktion AL/GPB-DA/PdA+ (Daniel Egloff,...
# 196              20  Motion Fraktion SVP (Roland Iseli, SVP): Einhe...
# 197              21  Motion Henri-Charles Beuchat (SVP): Gewalttäti...
# 198              22  Postulat Fraktion SVP (Alexander Feuz/Roland J...
# 199              23  Motion Henri-Charles Beuchat (SVP): Schluss mi...
# 200               1  Protokollgenehmigungen Stadtrat 2017 (Protokol...
# 201               2  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...
# 202               3  Kleine Anfrage Fraktion SVP (Alexander Feuz, S...
# 203               4  Gaswerkareal: Bericht Entwicklungs- und Planun...
# 204               5  Interfraktionelle Motion GB/JA!, GLP (Franzisk...
# 205               6  Motion Fraktion GB/JA! (Stéphanie Penher, GB/L...
# 206               7  Interpellation Fraktion GLP (Melanie Mettler, ...
# 207               8  Ratssekretariat: Antrag auf provisorische Anst...
# 208               9  Dringliche interfraktionelle Interpellation Fr...
# 209              10  Dringliche interfraktionelle Interpellation SV...
# 210              11  Dringliche interfraktionelle Motion SVP, BDP/C...
# 211              12  Dringliche Motion Fraktion SVP (Alexander Feuz...
# 212              13  Grundstück Bern 5/1354 (Lorrainestrasse 49 und...
# 213              14  Interfraktionelle Motion FDP, SVP, BDP/CVP (Ch...
# 214              15  Interfraktionelles Postulat BDP/CVP, FDP, GLP,...
# 215              16  Interfraktionelle Motion SVP, FDP, BDP/CVP (Ru...
# 216              17  Interpellation Fraktion SVP (Alexander Feuz/Ro...
# 217              18  Interfraktionelles Postulat SVP, FDP (Rudolf F...
# 218              19  Interfraktionelle Motion SVP, FDP (Rudolf Frie...
# 219              20  Motion Ingrid Kissling-Näf (SP) und Ueli Jaisl...
# 220              21  Interfraktionelle Motion FDP, SVP (Christoph Z...
# 221              22  Interfraktionelle Motion GB/JA!, GLP (Hasim Sa...
# 222              23  Interfraktionelle Motion FDP, SVP, BDP/CVP (Ch...
# 223               1  Wahl des Präsidiums und des Büros des Stadtrat...
# 224               2  Aufsichtskommission (AK): Wahl des Präsidiums ...
# 225               3  Kommission für Finanzen, Sicherheit und Umwelt...
# 226               4  Kommission für Planung, Verkehr und Stadtgrün ...
# 227               5  Kommission für Soziales, Bildung und Kultur (S...
# 228               6  Agglomerationskommission (AKO): Ersatzwahl ein...
# 229               7  Wahl in Schulkommission (Schulkommission Matte...
# 230               8  Kleine Anfrage Henri-Charles Beuchat (SVP): Na...
# 231               9  Kleine Anfrage Barbara Freiburghaus (FDP), Mil...
# 232              10  Dringliche Interpellation Lionel Gaudy, Philip...
# 233              11  Interfraktionelles Postulat SP, GFL, BDP/CVP (...
# 234              12  Jugendmotion (Paula Zysset/Frédéric Mader): EW...
# 235              13  Interfraktionelle Motion SVP, FDP (Rudolf Frie...
# 236              14  Interfraktionelle Interpellation BDP/CVP, FDP,...
# 237              15  Interfraktionelle Motion GFL/EVP, BDP/CVP, FDP...
# 238              16  Postulat Fraktion SP (Katharina Altas/Halua Pi...
# 239              17  Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# 240              18  Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# 241              19  Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
#
#     Beschluss Nr. Traktandumstatus       Beschluss       Datum      datum
# 192       2018-58      Beschlossen        Kenntnis  01.02.2018 2018-02-01
# 193       2018-59      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 194       2018-60      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 195       2018-61      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 196       2018-62      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 197       2018-63      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 198       2018-64      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 199       2018-65      Beschlossen    Verschiebung  01.02.2018 2018-02-01
# 200       2018-20      Beschlossen     Genehmigung  25.01.2018 2018-01-25
# 201       2018-21      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 202       2018-22      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 203       2018-23      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 204       2018-24      Beschlossen      Fristverl.  25.01.2018 2018-01-25
# 205       2018-25      Beschlossen      Fristverl.  25.01.2018 2018-01-25
# 206       2018-26      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 207       2018-27      Beschlossen            Wahl  25.01.2018 2018-01-25
# 208       2018-28      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 209       2018-29      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 210       2018-30      Beschlossen        Kenntnis  25.01.2018 2018-01-25
# 211       2018-31      Beschlossen       Ablehnung  25.01.2018 2018-01-25
# 212       2018-32      Beschlossen     Bewilligung  25.01.2018 2018-01-25
# 213       2018-33      Beschlossen       Ablehnung  25.01.2018 2018-01-25
# 214       2018-34      Beschlossen         Rückzug  25.01.2018 2018-01-25
# 215       2018-35      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 216       2018-36      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 217       2018-37      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 218       2018-38      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 219       2018-39      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 220       2018-40      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 221       2018-41      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 222       2018-42      Beschlossen    Verschiebung  25.01.2018 2018-01-25
# 223        2018-1      Beschlossen            Wahl  11.01.2018 2018-01-11
# 224        2018-2      Beschlossen            Wahl  11.01.2018 2018-01-11
# 225        2018-3      Beschlossen            Wahl  11.01.2018 2018-01-11
# 226        2018-4      Beschlossen            Wahl  11.01.2018 2018-01-11
# 227        2018-5      Beschlossen            Wahl  11.01.2018 2018-01-11
# 228        2018-6      Beschlossen            Wahl  11.01.2018 2018-01-11
# 229        2018-7      Beschlossen            Wahl  11.01.2018 2018-01-11
# 230        2018-8      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 231        2018-9      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 232       2018-10      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 233       2018-11      Beschlossen  Erheblicherkl.  11.01.2018 2018-01-11
# 234       2018-12      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 235       2018-13      Beschlossen       Ablehnung  11.01.2018 2018-01-11
# 236       2018-14      Beschlossen        Kenntnis  11.01.2018 2018-01-11
# 237       2018-15      Beschlossen       Ablehnung  11.01.2018 2018-01-11
# 238       2018-16      Beschlossen    Verschiebung  11.01.2018 2018-01-11
# 239       2018-17      Beschlossen    Verschiebung  11.01.2018 2018-01-11
# 240       2018-18      Beschlossen    Verschiebung  11.01.2018 2018-01-11
# 241       2018-19      Beschlossen    Verschiebung  11.01.2018 2018-01-11

# %%
len(df[df['Traktandierungstitel'].str.contains("Christa Ammann", na=False)])
# Out:
# 8

# %%
#Mehrere Konditionen:
df[(df.Traktandierungstitel.str.contains('Christa Ammann', na=False) & (df.Traktandumstatus == 'Beschlossen'))]
# Out:
#      Traktanden Nr.                               Traktandierungstitel  \
# 95               15  Dringliche interfraktionelle Motion SP/JUSO, G...
# 109               4  Motion Tamara Funiciello (JUSO), Christa Amman...
# 113               8  Interfraktionelle Motion AL/GPB-DA/PdA+, SP, G...
# 161              10  Dringliche interfraktionelle Motion GB/JA!, SP...
# 173              22  Interfraktionelle Motion AL/GPB-DA/PdA+, SP, G...
#
#     Beschluss Nr. Traktandumstatus                      Beschluss       Datum  \
# 95       2018-151      Beschlossen  Erheblicherkl. als Richtlinie  22.03.2018
# 109      2018-117      Beschlossen  Erheblicherkl. als Richtlinie  08.03.2018
# 113      2018-121      Beschlossen       Teilweise Erheblicherkl.  08.03.2018
# 161       2018-75      Beschlossen  Erheblicherkl. als Richtlinie  15.02.2018
# 173       2018-87      Beschlossen                   Verschiebung  15.02.2018
#
#          datum
# 95  2018-03-22
# 109 2018-03-08
# 113 2018-03-08
# 161 2018-02-15
# 173 2018-02-15

# %%
df.Traktandierungstitel.dtype
# Out:
# dtype('O')

# %%
df['Traktierungstitel'] = df['Traktandierungstitel'].astype(str)
df.dtypes
# Out:
# Traktanden Nr.                   int64
# Traktandierungstitel            object
# Beschluss Nr.                   object
# Traktandumstatus                object
# Beschluss                       object
# Datum                           object
# datum                   datetime64[ns]
# Traktierungstitel               object
# dtype: object

# %%
#Funktion für Vorstösse:
import re
def get_vorstoss(row):
    if re.findall(r"[\w]* Motion ", row['Traktandierungstitel']):   
        print('Motion')
        return 'Motion'
    
    elif re.findall(r"Motion ", row['Traktandierungstitel']):   
        print('Motion')
        return 'Motion'
    
    elif re.findall(r"[\w]* Postulat ", row['Traktandierungstitel']):   
        print('Postulat')
        return 'Postulat'
    
    elif re.findall(r"Postulat ", row['Traktandierungstitel']):   
        print('Postulat')
        return 'Postulat'
    
    elif re.findall(r"[\w]* Interpellation ", row['Traktandierungstitel']):   
        print('Interpellation')
        return 'Interpellation'
    
    elif re.findall(r"Interpellation ", row['Traktandierungstitel']):   
        print('Interpellation')
        return 'Interpellation'
    
    elif re.findall(r"[\w]* Anfrage ", row['Traktandierungstitel']):   
        print('Kleine Anfrage')
        return 'Kleine Anfrage'
    
    else:
        print('damn')

# %%
df['vorstoesse'] = df.apply(get_vorstoss,axis=1)
df.head()
# Out:
# Motion
# Motion
# Motion
# Motion
# Postulat
# Interpellation
# Interpellation
# damn
# damn
# damn
# damn
# damn
# Kleine Anfrage
# Kleine Anfrage
# damn
# Motion
# damn
# damn
# Motion
# Postulat
# damn
# damn
# damn
# Postulat
# Motion
# Motion
# Interpellation
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Postulat
# Postulat
# Postulat
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Postulat
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Kleine Anfrage
# Kleine Anfrage
# Interpellation
# damn
# Kleine Anfrage
# Motion
# damn
# damn
# Motion
# Motion
# Motion
# Motion
# damn
# damn
# Interpellation
# Motion
# damn
# damn
# Motion
# Motion
# Motion
# Motion
# Postulat
# Interpellation
# damn
# damn
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# damn
# damn
# damn
# damn
# damn
# Postulat
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Postulat
# Motion
# Motion
# Motion
# Motion
# Postulat
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# damn
# Postulat
# Motion
# Interpellation
# Postulat
# Motion
# Postulat
# Postulat
# Interpellation
# Kleine Anfrage
# Kleine Anfrage
# damn
# damn
# Postulat
# Interpellation
# Motion
# Motion
# Interpellation
# damn
# Motion
# Motion
# damn
# Postulat
# Motion
# Motion
# Motion
# Postulat
# Motion
# Motion
# Interpellation
# Motion
# Interpellation
# damn
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# Kleine Anfrage
# damn
# damn
# Motion
# Motion
# Motion
# Interpellation
# Postulat
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Postulat
# Interpellation
# Kleine Anfrage
# damn
# damn
# Motion
# Motion
# Motion
# Motion
# Motion
# Motion
# Postulat
# Postulat
# Postulat
# Motion
# Postulat
# Postulat
# Interpellation
# Motion
# Postulat
# Motion
# Motion
# Motion
# Postulat
# Motion
# damn
# Kleine Anfrage
# Kleine Anfrage
# damn
# Motion
# Motion
# Interpellation
# damn
# Interpellation
# Interpellation
# Motion
# Motion
# damn
# Motion
# Postulat
# Motion
# Interpellation
# Postulat
# Motion
# Motion
# Motion
# Motion
# Motion
# damn
# damn
# damn
# damn
# damn
# damn
# damn
# Kleine Anfrage
# Kleine Anfrage
# Interpellation
# Postulat
# damn
# Motion
# Interpellation
# Motion
# Postulat
# Motion
# Motion
# Motion
#    Traktanden Nr.                               Traktandierungstitel  \
# 0               1  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...
# 1              19  Dringliche interfraktionelle Motion FDP/JF, BD...
# 2              20  Motion Fraktion SVP (Alexander Feuz, SVP): Vel...
# 3              21  Motion Fraktion SP (Michael Sutter/David Stamp...
# 4              22  Postulat Fraktion SVP (Hans Ulrich Gränicher/A...
#
#   Beschluss Nr. Traktandumstatus     Beschluss       Datum      datum  \
# 0           NaN     Traktandiert           NaN  14.06.2018 2018-06-14
# 1      2018-321      Beschlossen  Verschiebung  14.06.2018 2018-06-14
# 2      2018-322      Beschlossen  Verschiebung  14.06.2018 2018-06-14
# 3      2018-323      Beschlossen  Verschiebung  14.06.2018 2018-06-14
# 4      2018-324      Beschlossen  Verschiebung  14.06.2018 2018-06-14
#
#                                    Traktierungstitel vorstoesse
# 0  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...     Motion
# 1  Dringliche interfraktionelle Motion FDP/JF, BD...     Motion
# 2  Motion Fraktion SVP (Alexander Feuz, SVP): Vel...     Motion
# 3  Motion Fraktion SP (Michael Sutter/David Stamp...     Motion
# 4  Postulat Fraktion SVP (Hans Ulrich Gränicher/A...   Postulat

# %%
df.vorstoesse.value_counts()
# Out:
# Motion            109
# Postulat           39
# Kleine Anfrage     26
# Interpellation     21
# Name: vorstoesse, dtype: int64

# %%
df.Traktandierungstitel
# Out:
# 0      Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...
# 1      Dringliche interfraktionelle Motion FDP/JF, BD...
# 2      Motion Fraktion SVP (Alexander Feuz, SVP): Vel...
# 3      Motion Fraktion SP (Michael Sutter/David Stamp...
# 4      Postulat Fraktion SVP (Hans Ulrich Gränicher/A...
# 5      Interpellation Fraktion SVP (Alexander Feuz/Ha...
# 6      Interpellation Fraktion SVP (Rudolf Friedli, S...
# 7      Protokollgenehmigung Stadtrat 2018 (Protokoll ...
# 8                   Aufsichtskommission (AK): Ersatzwahl
# 9      Kommission für Finanzen, Sicherheit und Umwelt...
# 10            Agglomerationskommission (AKO): Ersatzwahl
# 11     BERNMOBIL: Ersatzwahl Verwaltungsrat für die A...
# 12     Kleine Anfrage Barbara Freiburghaus (FDP): Ver...
# 13     Kleine Anfrage Fraktion GB/JA! (Ursina Andereg...
# 14                                    Jahresbericht 2017
# 15     Dringliche interfraktionelle Motion FDP/JF, BD...
# 16     Sanierung Thunstrasse West Projektierungskredi...
# 17     Verkehrsberuhigung Brunnadern-Elfenau Projekti...
# 18     Dringliche Motion Fraktion GB/JA! (Rahel Ruch,...
# 19     Postulat Fraktion SP (Benno Frauchiger/Martin ...
# 20     Bericht über die Verwaltungskontrollarbeit der...
# 21     Tätigkeitsbericht der Ombuds- und der Datenauf...
# 22                        Wasserstrategie der Stadt Bern
# 23     Dringliches interfraktionelles Postulat BDP/CV...
# 24     Dringliche Motion Fraktion FDP/JF (Bernhard Ei...
# 25     Dringliche Motion Fraktion GFL/EVP (Manuel C. ...
# 26     Dringliche Interpellation Freie Fraktion AL/Ga...
# 27     Interfraktionelle Motion GB/JA!, SP, GFL/EVP (...
# 28     Motion Fraktion SP/JUSO (Andreas Flückiger/Rol...
# 29     Interfraktionelles Postulat SP, GB/JA! (Peter ...
#                              ...
# 212    Grundstück Bern 5/1354 (Lorrainestrasse 49 und...
# 213    Interfraktionelle Motion FDP, SVP, BDP/CVP (Ch...
# 214    Interfraktionelles Postulat BDP/CVP, FDP, GLP,...
# 215    Interfraktionelle Motion SVP, FDP, BDP/CVP (Ru...
# 216    Interpellation Fraktion SVP (Alexander Feuz/Ro...
# 217    Interfraktionelles Postulat SVP, FDP (Rudolf F...
# 218    Interfraktionelle Motion SVP, FDP (Rudolf Frie...
# 219    Motion Ingrid Kissling-Näf (SP) und Ueli Jaisl...
# 220    Interfraktionelle Motion FDP, SVP (Christoph Z...
# 221    Interfraktionelle Motion GB/JA!, GLP (Hasim Sa...
# 222    Interfraktionelle Motion FDP, SVP, BDP/CVP (Ch...
# 223    Wahl des Präsidiums und des Büros des Stadtrat...
# 224    Aufsichtskommission (AK): Wahl des Präsidiums ...
# 225    Kommission für Finanzen, Sicherheit und Umwelt...
# 226    Kommission für Planung, Verkehr und Stadtgrün ...
# 227    Kommission für Soziales, Bildung und Kultur (S...
# 228    Agglomerationskommission (AKO): Ersatzwahl ein...
# 229    Wahl in Schulkommission (Schulkommission Matte...
# 230    Kleine Anfrage Henri-Charles Beuchat (SVP): Na...
# 231    Kleine Anfrage Barbara Freiburghaus (FDP), Mil...
# 232    Dringliche Interpellation Lionel Gaudy, Philip...
# 233    Interfraktionelles Postulat SP, GFL, BDP/CVP (...
# 234    Jugendmotion (Paula Zysset/Frédéric Mader): EW...
# 235    Interfraktionelle Motion SVP, FDP (Rudolf Frie...
# 236    Interfraktionelle Interpellation BDP/CVP, FDP,...
# 237    Interfraktionelle Motion GFL/EVP, BDP/CVP, FDP...
# 238    Postulat Fraktion SP (Katharina Altas/Halua Pi...
# 239    Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# 240    Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# 241    Motion Fraktion BDP/CVP (Michael Daphinoff, CV...
# Name: Traktandierungstitel, Length: 242, dtype: object

# %%
df.head()
# Out:
#    Traktanden Nr.                               Traktandierungstitel  \
# 0               1  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...
# 1              19  Dringliche interfraktionelle Motion FDP/JF, BD...
# 2              20  Motion Fraktion SVP (Alexander Feuz, SVP): Vel...
# 3              21  Motion Fraktion SP (Michael Sutter/David Stamp...
# 4              22  Postulat Fraktion SVP (Hans Ulrich Gränicher/A...
#
#   Beschluss Nr. Traktandumstatus     Beschluss       Datum      datum  \
# 0           NaN     Traktandiert           NaN  14.06.2018 2018-06-14
# 1      2018-321      Beschlossen  Verschiebung  14.06.2018 2018-06-14
# 2      2018-322      Beschlossen  Verschiebung  14.06.2018 2018-06-14
# 3      2018-323      Beschlossen  Verschiebung  14.06.2018 2018-06-14
# 4      2018-324      Beschlossen  Verschiebung  14.06.2018 2018-06-14
#
#                                    Traktierungstitel vorstoesse
# 0  Motion Fraktion AL/GPB-DA/PdA+ (Christa Ammann...     Motion
# 1  Dringliche interfraktionelle Motion FDP/JF, BD...     Motion
# 2  Motion Fraktion SVP (Alexander Feuz, SVP): Vel...     Motion
# 3  Motion Fraktion SP (Michael Sutter/David Stamp...     Motion
# 4  Postulat Fraktion SVP (Hans Ulrich Gränicher/A...   Postulat

# %%
import matplotlib.pyplot as plt
from cycler import cycler
import pywaffle
import numpy as np
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-82-d943c4092e71> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 from cycler import cycler
# ----> 3 from pywaffle import Waffle
#       4 import numpy as np
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'pywaffle'

# %%
ax = plt.pie(overall_df.Value, labels=overall_df.NAME, autopct=absolute_value)
fig = plt.gcf()
centercircle = plt.Circle((0,0),0.5, fc='white')
fig.gca().add_artist(centercircle)
fig.set_size_inches(10,10)
plt.savefig("overall_value_pie.pdf")
